# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
from sklearn.metrics import (
        make_scorer,
        confusion_matrix, 
        cohen_kappa_score, 
        accuracy_score, 
        precision_score, 
        recall_score, 
        f1_score, 
        roc_auc_score
)
from sklearn.model_selection import cross_validate, StratifiedKFold, train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier # decision trees for classification
from sklearn.neural_network import  MLPClassifier # neural networks for classification
from sklearn.naive_bayes import GaussianNB # naive bayes for classification
from sklearn.svm import SVC # support vector machines for classification

# %%
def specificity_score(y_true, y_pred):
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()
    return tn / (tn+fp)

# %%
METRICS = {
        "accuracy": make_scorer(accuracy_score),
        "precision": make_scorer(precision_score),
        "recall": make_scorer(recall_score),
        "f1": make_scorer(f1_score),
        "AUC": make_scorer(roc_auc_score, needs_proba=True),
        "specificity": make_scorer(specificity_score),
        "kappa":make_scorer(cohen_kappa_score)
}

# %% [markdown]
# ### upload and divide data

# %%
#d = pd.read_csv("data/03-pico-sem-town-shortname.csv")
#d = pd.read_csv("data/03-idf.csv")
#d = pd.read_csv("data/03-idf.csv")
d = pd.read_csv("data/03-idf-completo-fixedq.csv")
#d=d.dropna()

# %%
# sample data? faster models
#d = d.sample(frac=0.01)

# %%
d.isna().sum().sum()
# Out:
# 68

# %%
X, y = d.drop("target", axis=1), d["target"]

# %% [markdown]
# ### prepare for cross validation and/or train/test split

# %%
# cross-validation splitting strategy
splitter = StratifiedKFold(n_splits=10, shuffle=True, random_state=1234)

# %%
# train/test split
# https://towardsdatascience.com/understanding-the-confusion-matrix-and-how-to-implement-it-in-python-319202e0fe4d
test_size = 0.33
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size = test_size, random_state=1234, stratify=y)

# %% [markdown]
# # Modelos

# %% [markdown]
# ### demo_python

# %% [markdown]
# - ## decision tree

# %%
dt = DecisionTreeClassifier(max_depth=25, random_state=1234)

# %% [markdown]
# cross validate

# %%
scores = cross_validate(dt, X, y, cv=splitter, scoring=METRICS)
dt_scores = pd.DataFrame(scores)
pd.DataFrame(dt_scores.mean()).T

# %% [markdown]
# train/test split

# %%
dt.fit(xtrain, ytrain)
ypred = dt.predict(xtest)
cm = confusion_matrix(ytest,ypred) 
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
dt_f1 = (2*tp)/(2*tp+fp+fn)
print(dt_f1)

# %% [markdown]
# - ## neural network

# %%
nn = MLPClassifier(hidden_layer_sizes=(50,50), max_iter=20, random_state=1234)

# %% [markdown]
# cross validate

# %%
scores_nn = cross_validate(nn, X, y, cv=splitter, scoring=METRICS)
nn_scores = pd.DataFrame(scores_nn)
pd.DataFrame(nn_scores.mean()).T

# %% [markdown]
# train/test split

# %%
nn.fit(xtrain, ytrain)
ypred = nn.predict(xtest)
cm = confusion_matrix(ytest,ypred) 
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
nn_f1 = (2*tp)/(2*tp+fp+fn)
print(nn_f1)

# %% [markdown]
# - ## gaussian naive bayes

# %%
nb = GaussianNB()
scores_nb = cross_validate(nb, X, y, cv=splitter, scoring=METRICS)
nb_scores = pd.DataFrame(scores_nb)
pd.DataFrame(nb_scores.mean()).T

# %% [markdown]
# - ## support vector classification

# %%
svm = SVC(random_state=1234, probability=True)
scores_svm = cross_validate(svm, X, y, cv=splitter, scoring=METRICS)
svm_scores = pd.DataFrame(scores_svm)
pd.DataFrame(svm_scores.mean()).T

# %% [markdown]
# - ## nearest neighbors

# %%
from sklearn.neighbors import NearestNeighbors
nbrs = NearestNeighbors(n_neighbors=2, algorithm='ball_tree')

# %%
nbrs.fit(xtrain)
ypred = nbrs.predict(xtest)
cm = confusion_matrix(ytest,ypred) 
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
nbrs_f1 = (2*tp)/(2*tp+fp+fn)
print(nbrs_f1)

# %% [markdown]
# - ## nearest centroid

# %%
from sklearn.neighbors import NearestCentroid
nc = NearestCentroid()
scores_nc = cross_validate(nc, X, y, cv=splitter, scoring=METRICS)
clf_scores = pd.DataFrame(scores_nc)
pd.DataFrame(nc_scores.mean()).T

# %% [markdown]
# ### ensembles

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier, GradientBoostingClassifier

# %% [markdown]
# - ## random forest

# %%
clf = RandomForestClassifier(n_estimators=20, max_depth=None, min_samples_split=2, random_state=0)

# %% [markdown]
# cross validate

# %%
scores_clf = cross_validate(clf, X, y, cv=splitter, scoring=METRICS)
clf_scores = pd.DataFrame(scores_clf)
pd.DataFrame(clf_scores.mean()).T

# %% [markdown]
# train/test split

# %%
clf.fit(xtrain, ytrain)
ypred = clf.predict(xtest)
cm = confusion_matrix(ytest,ypred) 
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
clf_f1 = (2*tp)/(2*tp+fp+fn)
print(clf_f1)

# %% [markdown]
# - ## adaboost

# %%
ada = AdaBoostClassifier(n_estimators=100)

# %% [markdown]
# cross validate

# %%
scores_ada = cross_validate(ada, X, y, cv=splitter, scoring=METRICS)
ada_scores = pd.DataFrame(scores_ada)
pd.DataFrame(ada_scores.mean()).T

# %% [markdown]
# train/test split

# %%
ada.fit(xtrain, ytrain)
ypred = ada.predict(xtest)
cm = confusion_matrix(ytest,ypred) 
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
ada_f1 = (2*tp)/(2*tp+fp+fn)
print(ada_f1)

# %% [markdown]
# - ## gradient boost

# %%
gbc = GradientBoostingClassifier(n_estimators=250, learning_rate=1.0, max_depth=20, random_state=0).fit(X, y)
scores_gbc = cross_validate(gbc, X, y, cv=splitter, scoring=METRICS)
gbc_scores = pd.DataFrame(scores_gbc)
pd.DataFrame(gbc_scores.mean()).T

# %% [markdown]
# ### tpot automl

# %% [markdown]
# - ## xgboost

# %%
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier(objective = 'binary:logistic',seed=42)
#learning_rate=0.1, max_depth=25, min_child_weight=16, n_estimators=100, n_jobs=1, subsample=0.8500000000000001, verbosity=0,

# %% [markdown]
# cross-validate

# %%
scores_xgb = cross_validate(xgb, X, y, cv=splitter, scoring=METRICS)
xgb_scores = pd.DataFrame(scores_xgb)
pd.DataFrame(xgb_scores.mean()).T

# %% [markdown]
# train/test split

# %%
# train/test
#xgb.fit(xtrain, ytrain, verbose=True, early_stopping_rounds=10, eval_metric='map', eval_set=[(xtest,ytest)])
#ypred = xgb.predict(xtest)
cm = confusion_matrix(ytest,ypred) 
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
f1 = (2*tp)/(2*tp+fp+fn)
print(f1)
# Out:
# 0.7544177720659109

# %% [markdown]
# ### xgboost youtube
# - https://www.youtube.com/watch?v=ap2SS0-XPcE

# %%
model_xgboost = XGBClassifier(learning_rate=0.1,
                                      max_depth=5,
                                      n_estimators=5000,
                                      subsample=0.5,
                                      colsample_bytree=0.5,
                                      eval_metric='map',
                                      verbosity=1)

eval_set = [(xtest, ytest)]

model_xgboost.fit(xtrain,
                  ytrain,
                  early_stopping_rounds=10,
                  eval_set=eval_set,
                  verbose=True)
# Out:
# [0]	validation_0-map:0.70657
# [1]	validation_0-map:0.72107
# [2]	validation_0-map:0.73143
# [3]	validation_0-map:0.73398
# [4]	validation_0-map:0.74036
# [5]	validation_0-map:0.74520
# [6]	validation_0-map:0.74652
# [7]	validation_0-map:0.75027
# [8]	validation_0-map:0.75119
# [9]	validation_0-map:0.75281
# [10]	validation_0-map:0.75338
# [11]	validation_0-map:0.75364
# [12]	validation_0-map:0.75461
# [13]	validation_0-map:0.75471
# [14]	validation_0-map:0.75567
# [15]	validation_0-map:0.75734
# [16]	validation_0-map:0.75805
# [17]	validation_0-map:0.75798
# [18]	validation_0-map:0.75773
# [19]	validation_0-map:0.75740
# [20]	validation_0-map:0.75747
# [21]	validation_0-map:0.75786
# [22]	validation_0-map:0.75930
# [23]	validation_0-map:0.76025
# [24]	validation_0-map:0.76058
# [25]	validation_0-map:0.76172
# [26]	validation_0-map:0.76266
# [27]	validation_0-map:0.76306
# [28]	validation_0-map:0.76361
# [29]	validation_0-map:0.76382
# [30]	validation_0-map:0.76430
# [31]	validation_0-map:0.76496
# [32]	validation_0-map:0.76502
# [33]	validation_0-map:0.76525
# [34]	validation_0-map:0.76674
# [35]	validation_0-map:0.76691
# [36]	validation_0-map:0.76726
# [37]	validation_0-map:0.76801
# [38]	validation_0-map:0.76854
# [39]	validation_0-map:0.76919
# [40]	validation_0-map:0.76964
# [41]	validation_0-map:0.77007
# [42]	validation_0-map:0.77040
# [43]	validation_0-map:0.77095
# [44]	validation_0-map:0.77116
# [45]	validation_0-map:0.77152
# [46]	validation_0-map:0.77175
# [47]	validation_0-map:0.77258
# [48]	validation_0-map:0.77303
# [49]	validation_0-map:0.77369
# [50]	validation_0-map:0.77382
# [51]	validation_0-map:0.77429
# [52]	validation_0-map:0.77440
# [53]	validation_0-map:0.77485
# [54]	validation_0-map:0.77516
# [55]	validation_0-map:0.77574
# [56]	validation_0-map:0.77611
# [57]	validation_0-map:0.77621
# [58]	validation_0-map:0.77628
# [59]	validation_0-map:0.77639
# [60]	validation_0-map:0.77659
# [61]	validation_0-map:0.77693
# [62]	validation_0-map:0.77748
# [63]	validation_0-map:0.77787
# [64]	validation_0-map:0.77806
# [65]	validation_0-map:0.77842
# [66]	validation_0-map:0.77861
# [67]	validation_0-map:0.77903
# [68]	validation_0-map:0.77927
# [69]	validation_0-map:0.77949
# [70]	validation_0-map:0.77949
# [71]	validation_0-map:0.77956
# [72]	validation_0-map:0.77993
# [73]	validation_0-map:0.78019
# [74]	validation_0-map:0.78037
# [75]	validation_0-map:0.78064
# [76]	validation_0-map:0.78091
# [77]	validation_0-map:0.78122
# [78]	validation_0-map:0.78131
# [79]	validation_0-map:0.78145
# [80]	validation_0-map:0.78150
# [81]	validation_0-map:0.78161
# [82]	validation_0-map:0.78169
# [83]	validation_0-map:0.78172
# [84]	validation_0-map:0.78194
# [85]	validation_0-map:0.78230
# [86]	validation_0-map:0.78240
# [87]	validation_0-map:0.78272
# [88]	validation_0-map:0.78280
# [89]	validation_0-map:0.78279
# [90]	validation_0-map:0.78290
# [91]	validation_0-map:0.78293
# [92]	validation_0-map:0.78319
# [93]	validation_0-map:0.78323
# [94]	validation_0-map:0.78324
# [95]	validation_0-map:0.78347
# [96]	validation_0-map:0.78351
# [97]	validation_0-map:0.78379
# [98]	validation_0-map:0.78386
# [99]	validation_0-map:0.78395
# [100]	validation_0-map:0.78416
# [101]	validation_0-map:0.78429
# [102]	validation_0-map:0.78439
# [103]	validation_0-map:0.78445
# [104]	validation_0-map:0.78461
# [105]	validation_0-map:0.78465
# [106]	validation_0-map:0.78482
# [107]	validation_0-map:0.78499
# [108]	validation_0-map:0.78504
# [109]	validation_0-map:0.78505
# [110]	validation_0-map:0.78530
# [111]	validation_0-map:0.78558
# [112]	validation_0-map:0.78588
# [113]	validation_0-map:0.78603
# [114]	validation_0-map:0.78607
# [115]	validation_0-map:0.78613
# [116]	validation_0-map:0.78634
# [117]	validation_0-map:0.78644
# [118]	validation_0-map:0.78663
# [119]	validation_0-map:0.78687
# [120]	validation_0-map:0.78709
# [121]	validation_0-map:0.78728
# [122]	validation_0-map:0.78729
# [123]	validation_0-map:0.78730
# [124]	validation_0-map:0.78761
# [125]	validation_0-map:0.78779
# [126]	validation_0-map:0.78790
# [127]	validation_0-map:0.78794
# [128]	validation_0-map:0.78798
# [129]	validation_0-map:0.78809
# [130]	validation_0-map:0.78814
# [131]	validation_0-map:0.78830
# [132]	validation_0-map:0.78846
# [133]	validation_0-map:0.78847
# [134]	validation_0-map:0.78862
# [135]	validation_0-map:0.78874
# [136]	validation_0-map:0.78882
# [137]	validation_0-map:0.78904
# [138]	validation_0-map:0.78909
# [139]	validation_0-map:0.78922
# [140]	validation_0-map:0.78930
# [141]	validation_0-map:0.78939
# [142]	validation_0-map:0.78942
# [143]	validation_0-map:0.78946
# [144]	validation_0-map:0.78962
# [145]	validation_0-map:0.78964
# [146]	validation_0-map:0.78966
# [147]	validation_0-map:0.78984
# [148]	validation_0-map:0.78996
# [149]	validation_0-map:0.79008
# [150]	validation_0-map:0.79011
# [151]	validation_0-map:0.79030
# [152]	validation_0-map:0.79037
# [153]	validation_0-map:0.79042
# [154]	validation_0-map:0.79056
# [155]	validation_0-map:0.79071
# [156]	validation_0-map:0.79081
# [157]	validation_0-map:0.79091
# [158]	validation_0-map:0.79098
# [159]	validation_0-map:0.79106
# [160]	validation_0-map:0.79129
# [161]	validation_0-map:0.79146
# [162]	validation_0-map:0.79153
# [163]	validation_0-map:0.79162
# [164]	validation_0-map:0.79165
# [165]	validation_0-map:0.79168
# [166]	validation_0-map:0.79176
# [167]	validation_0-map:0.79186
# [168]	validation_0-map:0.79195
# [169]	validation_0-map:0.79204
# [170]	validation_0-map:0.79210
# [171]	validation_0-map:0.79224
# [172]	validation_0-map:0.79231
# [173]	validation_0-map:0.79241
# [174]	validation_0-map:0.79253
# [175]	validation_0-map:0.79265
# [176]	validation_0-map:0.79264
# [177]	validation_0-map:0.79265
# [178]	validation_0-map:0.79276
# [179]	validation_0-map:0.79279
# [180]	validation_0-map:0.79287
# [181]	validation_0-map:0.79291
# [182]	validation_0-map:0.79295
# [183]	validation_0-map:0.79300
# [184]	validation_0-map:0.79308
# [185]	validation_0-map:0.79315
# [186]	validation_0-map:0.79324
# [187]	validation_0-map:0.79330
# [188]	validation_0-map:0.79334
# [189]	validation_0-map:0.79336
# [190]	validation_0-map:0.79348
# [191]	validation_0-map:0.79358
# [192]	validation_0-map:0.79363
# [193]	validation_0-map:0.79367
# [194]	validation_0-map:0.79374
# [195]	validation_0-map:0.79381
# [196]	validation_0-map:0.79385
# [197]	validation_0-map:0.79392
# [198]	validation_0-map:0.79396
# [199]	validation_0-map:0.79398
# [200]	validation_0-map:0.79410
# [201]	validation_0-map:0.79420
# [202]	validation_0-map:0.79421
# [203]	validation_0-map:0.79432
# [204]	validation_0-map:0.79433
# [205]	validation_0-map:0.79444
# [206]	validation_0-map:0.79452
# [207]	validation_0-map:0.79452
# [208]	validation_0-map:0.79463
# [209]	validation_0-map:0.79474
# [210]	validation_0-map:0.79478
# [211]	validation_0-map:0.79488
# [212]	validation_0-map:0.79499
# [213]	validation_0-map:0.79505
# [214]	validation_0-map:0.79516
# [215]	validation_0-map:0.79520
# [216]	validation_0-map:0.79524
# [217]	validation_0-map:0.79527
# [218]	validation_0-map:0.79531
# [219]	validation_0-map:0.79539
# [220]	validation_0-map:0.79547
# [221]	validation_0-map:0.79548
# [222]	validation_0-map:0.79554
# [223]	validation_0-map:0.79556
# [224]	validation_0-map:0.79557
# [225]	validation_0-map:0.79564
# [226]	validation_0-map:0.79571
# [227]	validation_0-map:0.79577
# [228]	validation_0-map:0.79586
# [229]	validation_0-map:0.79588
# [230]	validation_0-map:0.79591
# [231]	validation_0-map:0.79596
# [232]	validation_0-map:0.79605
# [233]	validation_0-map:0.79604
# [234]	validation_0-map:0.79614
# [235]	validation_0-map:0.79614
# [236]	validation_0-map:0.79618
# [237]	validation_0-map:0.79620
# [238]	validation_0-map:0.79629
# [239]	validation_0-map:0.79629
# [240]	validation_0-map:0.79634
# [241]	validation_0-map:0.79641
# [242]	validation_0-map:0.79644
# [243]	validation_0-map:0.79646
# [244]	validation_0-map:0.79652
# [245]	validation_0-map:0.79656
# [246]	validation_0-map:0.79659
# [247]	validation_0-map:0.79666
# [248]	validation_0-map:0.79673
# [249]	validation_0-map:0.79674
# [250]	validation_0-map:0.79679
# [251]	validation_0-map:0.79690
# [252]	validation_0-map:0.79692
# [253]	validation_0-map:0.79693
# [254]	validation_0-map:0.79699
# [255]	validation_0-map:0.79704
# [256]	validation_0-map:0.79706
# [257]	validation_0-map:0.79710
# [258]	validation_0-map:0.79719
# [259]	validation_0-map:0.79722
# [260]	validation_0-map:0.79725
# [261]	validation_0-map:0.79727
# [262]	validation_0-map:0.79729
# [263]	validation_0-map:0.79733
# [264]	validation_0-map:0.79735
# [265]	validation_0-map:0.79744
# [266]	validation_0-map:0.79746
# [267]	validation_0-map:0.79757
# [268]	validation_0-map:0.79758
# [269]	validation_0-map:0.79758
# [270]	validation_0-map:0.79761
# [271]	validation_0-map:0.79761
# [272]	validation_0-map:0.79764
# [273]	validation_0-map:0.79768
# [274]	validation_0-map:0.79775
# [275]	validation_0-map:0.79782
# [276]	validation_0-map:0.79787
# [277]	validation_0-map:0.79793
# [278]	validation_0-map:0.79796
# [279]	validation_0-map:0.79802
# [280]	validation_0-map:0.79805
# [281]	validation_0-map:0.79809
# [282]	validation_0-map:0.79815
# [283]	validation_0-map:0.79819
# [284]	validation_0-map:0.79823
# [285]	validation_0-map:0.79829
# [286]	validation_0-map:0.79832
# [287]	validation_0-map:0.79837
# [288]	validation_0-map:0.79838
# [289]	validation_0-map:0.79840
# [290]	validation_0-map:0.79842
# [291]	validation_0-map:0.79846
# [292]	validation_0-map:0.79848
# [293]	validation_0-map:0.79852
# [294]	validation_0-map:0.79855
# [295]	validation_0-map:0.79857
# [296]	validation_0-map:0.79862
# [297]	validation_0-map:0.79862
# [298]	validation_0-map:0.79865
# [299]	validation_0-map:0.79872
# [300]	validation_0-map:0.79871
# [301]	validation_0-map:0.79873
# [302]	validation_0-map:0.79880
# [303]	validation_0-map:0.79885
# [304]	validation_0-map:0.79890
# [305]	validation_0-map:0.79891
# [306]	validation_0-map:0.79892
# [307]	validation_0-map:0.79896
# [308]	validation_0-map:0.79901
# [309]	validation_0-map:0.79903
# [310]	validation_0-map:0.79904
# [311]	validation_0-map:0.79907
# [312]	validation_0-map:0.79909
# [313]	validation_0-map:0.79912
# [314]	validation_0-map:0.79913
# [315]	validation_0-map:0.79917
# [316]	validation_0-map:0.79917
# [317]	validation_0-map:0.79920
# [318]	validation_0-map:0.79926
# [319]	validation_0-map:0.79927
# [320]	validation_0-map:0.79930
# [321]	validation_0-map:0.79935
# [322]	validation_0-map:0.79938
# [323]	validation_0-map:0.79944
# [324]	validation_0-map:0.79945
# [325]	validation_0-map:0.79951
# [326]	validation_0-map:0.79954
# [327]	validation_0-map:0.79958
# [328]	validation_0-map:0.79959
# [329]	validation_0-map:0.79963
# [330]	validation_0-map:0.79968
# [331]	validation_0-map:0.79970
# [332]	validation_0-map:0.79971
# [333]	validation_0-map:0.79976
# [334]	validation_0-map:0.79976
# [335]	validation_0-map:0.79979
# [336]	validation_0-map:0.79982
# [337]	validation_0-map:0.79983
# [338]	validation_0-map:0.79986
# [339]	validation_0-map:0.79987
# [340]	validation_0-map:0.79992
# [341]	validation_0-map:0.79993
# [342]	validation_0-map:0.79996
# [343]	validation_0-map:0.80000
# [344]	validation_0-map:0.80002
# [345]	validation_0-map:0.80002
# [346]	validation_0-map:0.80005
# [347]	validation_0-map:0.80008
# [348]	validation_0-map:0.80011
# [349]	validation_0-map:0.80014
# [350]	validation_0-map:0.80021
# [351]	validation_0-map:0.80024
# [352]	validation_0-map:0.80026
# [353]	validation_0-map:0.80027
# [354]	validation_0-map:0.80030
# [355]	validation_0-map:0.80033
# [356]	validation_0-map:0.80034
# [357]	validation_0-map:0.80037
# [358]	validation_0-map:0.80040
# [359]	validation_0-map:0.80043
# [360]	validation_0-map:0.80047
# [361]	validation_0-map:0.80053
# [362]	validation_0-map:0.80057
# [363]	validation_0-map:0.80060
# [364]	validation_0-map:0.80060
# [365]	validation_0-map:0.80064
# [366]	validation_0-map:0.80065
# [367]	validation_0-map:0.80068
# [368]	validation_0-map:0.80071
# [369]	validation_0-map:0.80073
# [370]	validation_0-map:0.80075
# [371]	validation_0-map:0.80075
# [372]	validation_0-map:0.80077
# [373]	validation_0-map:0.80080
# [374]	validation_0-map:0.80081
# [375]	validation_0-map:0.80082
# [376]	validation_0-map:0.80083
# [377]	validation_0-map:0.80084
# [378]	validation_0-map:0.80084
# [379]	validation_0-map:0.80085
# [380]	validation_0-map:0.80086
# [381]	validation_0-map:0.80088
# [382]	validation_0-map:0.80092
# [383]	validation_0-map:0.80093
# [384]	validation_0-map:0.80093
# [385]	validation_0-map:0.80097
# [386]	validation_0-map:0.80103
# [387]	validation_0-map:0.80107
# [388]	validation_0-map:0.80108
# [389]	validation_0-map:0.80109
# [390]	validation_0-map:0.80110
# [391]	validation_0-map:0.80112
# [392]	validation_0-map:0.80115
# [393]	validation_0-map:0.80118
# [394]	validation_0-map:0.80118
# [395]	validation_0-map:0.80121
# [396]	validation_0-map:0.80128
# [397]	validation_0-map:0.80128
# [398]	validation_0-map:0.80134
# [399]	validation_0-map:0.80136
# [400]	validation_0-map:0.80142
# [401]	validation_0-map:0.80144
# [402]	validation_0-map:0.80147
# [403]	validation_0-map:0.80148
# [404]	validation_0-map:0.80150
# [405]	validation_0-map:0.80154
# [406]	validation_0-map:0.80159
# [407]	validation_0-map:0.80162
# [408]	validation_0-map:0.80165
# [409]	validation_0-map:0.80166
# [410]	validation_0-map:0.80166
# [411]	validation_0-map:0.80168
# [412]	validation_0-map:0.80169
# [413]	validation_0-map:0.80172
# [414]	validation_0-map:0.80172
# [415]	validation_0-map:0.80176
# [416]	validation_0-map:0.80178
# [417]	validation_0-map:0.80180
# [418]	validation_0-map:0.80183
# [419]	validation_0-map:0.80185
# [420]	validation_0-map:0.80187
# [421]	validation_0-map:0.80189
# [422]	validation_0-map:0.80189
# [423]	validation_0-map:0.80192
# [424]	validation_0-map:0.80195
# [425]	validation_0-map:0.80196
# [426]	validation_0-map:0.80196
# [427]	validation_0-map:0.80200
# [428]	validation_0-map:0.80202
# [429]	validation_0-map:0.80201
# [430]	validation_0-map:0.80202
# [431]	validation_0-map:0.80204
# [432]	validation_0-map:0.80204
# [433]	validation_0-map:0.80206
# [434]	validation_0-map:0.80206
# [435]	validation_0-map:0.80207
# [436]	validation_0-map:0.80209
# [437]	validation_0-map:0.80213
# [438]	validation_0-map:0.80216
# [439]	validation_0-map:0.80219
# [440]	validation_0-map:0.80220
# [441]	validation_0-map:0.80223
# [442]	validation_0-map:0.80225
# [443]	validation_0-map:0.80231
# [444]	validation_0-map:0.80235
# [445]	validation_0-map:0.80236
# [446]	validation_0-map:0.80239
# [447]	validation_0-map:0.80241
# [448]	validation_0-map:0.80242
# [449]	validation_0-map:0.80243
# [450]	validation_0-map:0.80244
# [451]	validation_0-map:0.80246
# [452]	validation_0-map:0.80248
# [453]	validation_0-map:0.80250
# [454]	validation_0-map:0.80250
# [455]	validation_0-map:0.80254
# [456]	validation_0-map:0.80255
# [457]	validation_0-map:0.80257
# [458]	validation_0-map:0.80257
# [459]	validation_0-map:0.80258
# [460]	validation_0-map:0.80259
# [461]	validation_0-map:0.80261
# [462]	validation_0-map:0.80260
# [463]	validation_0-map:0.80261
# [464]	validation_0-map:0.80262
# [465]	validation_0-map:0.80264
# [466]	validation_0-map:0.80265
# [467]	validation_0-map:0.80266
# [468]	validation_0-map:0.80268
# [469]	validation_0-map:0.80271
# [470]	validation_0-map:0.80273
# [471]	validation_0-map:0.80278
# [472]	validation_0-map:0.80280
# [473]	validation_0-map:0.80281
# [474]	validation_0-map:0.80284
# [475]	validation_0-map:0.80285
# [476]	validation_0-map:0.80285
# [477]	validation_0-map:0.80287
# [478]	validation_0-map:0.80288
# [479]	validation_0-map:0.80290
# [480]	validation_0-map:0.80294
# [481]	validation_0-map:0.80295
# [482]	validation_0-map:0.80297
# [483]	validation_0-map:0.80297
# [484]	validation_0-map:0.80300
# [485]	validation_0-map:0.80301
# [486]	validation_0-map:0.80302
# [487]	validation_0-map:0.80303
# [488]	validation_0-map:0.80304
# [489]	validation_0-map:0.80309
# [490]	validation_0-map:0.80309
# [491]	validation_0-map:0.80309
# [492]	validation_0-map:0.80310
# [493]	validation_0-map:0.80310
# [494]	validation_0-map:0.80311
# [495]	validation_0-map:0.80312
# [496]	validation_0-map:0.80312
# [497]	validation_0-map:0.80314
# [498]	validation_0-map:0.80316
# [499]	validation_0-map:0.80320
# [500]	validation_0-map:0.80321
# [501]	validation_0-map:0.80323
# [502]	validation_0-map:0.80326
# [503]	validation_0-map:0.80328
# [504]	validation_0-map:0.80329
# [505]	validation_0-map:0.80330
# [506]	validation_0-map:0.80334
# [507]	validation_0-map:0.80334
# [508]	validation_0-map:0.80335
# [509]	validation_0-map:0.80336
# [510]	validation_0-map:0.80337
# [511]	validation_0-map:0.80337
# [512]	validation_0-map:0.80341
# [513]	validation_0-map:0.80342
# [514]	validation_0-map:0.80344
# [515]	validation_0-map:0.80345
# [516]	validation_0-map:0.80344
# [517]	validation_0-map:0.80348
# [518]	validation_0-map:0.80349
# [519]	validation_0-map:0.80349
# [520]	validation_0-map:0.80351
# [521]	validation_0-map:0.80354
# [522]	validation_0-map:0.80356
# [523]	validation_0-map:0.80357
# [524]	validation_0-map:0.80357
# [525]	validation_0-map:0.80358
# [526]	validation_0-map:0.80361
# [527]	validation_0-map:0.80361
# [528]	validation_0-map:0.80363
# [529]	validation_0-map:0.80364
# [530]	validation_0-map:0.80364
# [531]	validation_0-map:0.80366
# [532]	validation_0-map:0.80366
# [533]	validation_0-map:0.80368
# [534]	validation_0-map:0.80368
# [535]	validation_0-map:0.80369
# [536]	validation_0-map:0.80370
# [537]	validation_0-map:0.80371
# [538]	validation_0-map:0.80373
# [539]	validation_0-map:0.80377
# [540]	validation_0-map:0.80377
# [541]	validation_0-map:0.80378
# [542]	validation_0-map:0.80379
# [543]	validation_0-map:0.80382
# [544]	validation_0-map:0.80383
# [545]	validation_0-map:0.80384
# [546]	validation_0-map:0.80384
# [547]	validation_0-map:0.80386
# [548]	validation_0-map:0.80389
# [549]	validation_0-map:0.80391
# [550]	validation_0-map:0.80392
# [551]	validation_0-map:0.80393
# [552]	validation_0-map:0.80394
# [553]	validation_0-map:0.80395
# [554]	validation_0-map:0.80397
# [555]	validation_0-map:0.80399
# [556]	validation_0-map:0.80401
# [557]	validation_0-map:0.80400
# [558]	validation_0-map:0.80405
# [559]	validation_0-map:0.80405
# [560]	validation_0-map:0.80407
# [561]	validation_0-map:0.80409
# [562]	validation_0-map:0.80412
# [563]	validation_0-map:0.80414
# [564]	validation_0-map:0.80413
# [565]	validation_0-map:0.80413
# [566]	validation_0-map:0.80415
# [567]	validation_0-map:0.80416
# [568]	validation_0-map:0.80419
# [569]	validation_0-map:0.80422
# [570]	validation_0-map:0.80423
# [571]	validation_0-map:0.80427
# [572]	validation_0-map:0.80429
# [573]	validation_0-map:0.80433
# [574]	validation_0-map:0.80433
# [575]	validation_0-map:0.80435
# [576]	validation_0-map:0.80435
# [577]	validation_0-map:0.80438
# [578]	validation_0-map:0.80441
# [579]	validation_0-map:0.80444
# [580]	validation_0-map:0.80446
# [581]	validation_0-map:0.80446
# [582]	validation_0-map:0.80446
# [583]	validation_0-map:0.80446
# [584]	validation_0-map:0.80450
# [585]	validation_0-map:0.80451
# [586]	validation_0-map:0.80453
# [587]	validation_0-map:0.80454
# [588]	validation_0-map:0.80456
# [589]	validation_0-map:0.80457
# [590]	validation_0-map:0.80458
# [591]	validation_0-map:0.80461
# [592]	validation_0-map:0.80462
# [593]	validation_0-map:0.80463
# [594]	validation_0-map:0.80464
# [595]	validation_0-map:0.80467
# [596]	validation_0-map:0.80470
# [597]	validation_0-map:0.80470
# [598]	validation_0-map:0.80472
# [599]	validation_0-map:0.80472
# [600]	validation_0-map:0.80474
# [601]	validation_0-map:0.80477
# [602]	validation_0-map:0.80480
# [603]	validation_0-map:0.80480
# [604]	validation_0-map:0.80483
# [605]	validation_0-map:0.80485
# [606]	validation_0-map:0.80485
# [607]	validation_0-map:0.80487
# [608]	validation_0-map:0.80487
# [609]	validation_0-map:0.80488
# [610]	validation_0-map:0.80489
# [611]	validation_0-map:0.80490
# [612]	validation_0-map:0.80492
# [613]	validation_0-map:0.80494
# [614]	validation_0-map:0.80495
# [615]	validation_0-map:0.80497
# [616]	validation_0-map:0.80497
# [617]	validation_0-map:0.80499
# [618]	validation_0-map:0.80500
# [619]	validation_0-map:0.80502
# [620]	validation_0-map:0.80502
# [621]	validation_0-map:0.80506
# [622]	validation_0-map:0.80506
# [623]	validation_0-map:0.80508
# [624]	validation_0-map:0.80507
# [625]	validation_0-map:0.80508
# [626]	validation_0-map:0.80510
# [627]	validation_0-map:0.80510
# [628]	validation_0-map:0.80511
# [629]	validation_0-map:0.80512
# [630]	validation_0-map:0.80512
# [631]	validation_0-map:0.80513
# [632]	validation_0-map:0.80514
# [633]	validation_0-map:0.80515
# [634]	validation_0-map:0.80516
# [635]	validation_0-map:0.80516
# [636]	validation_0-map:0.80516
# [637]	validation_0-map:0.80518
# [638]	validation_0-map:0.80519
# [639]	validation_0-map:0.80519
# [640]	validation_0-map:0.80520
# [641]	validation_0-map:0.80520
# [642]	validation_0-map:0.80520
# [643]	validation_0-map:0.80520
# [644]	validation_0-map:0.80521
# [645]	validation_0-map:0.80523
# [646]	validation_0-map:0.80524
# [647]	validation_0-map:0.80525
# [648]	validation_0-map:0.80527
# [649]	validation_0-map:0.80528
# [650]	validation_0-map:0.80529
# [651]	validation_0-map:0.80530
# [652]	validation_0-map:0.80532
# [653]	validation_0-map:0.80532
# [654]	validation_0-map:0.80532
# [655]	validation_0-map:0.80534
# [656]	validation_0-map:0.80534
# [657]	validation_0-map:0.80534
# [658]	validation_0-map:0.80535
# [659]	validation_0-map:0.80536
# [660]	validation_0-map:0.80538
# [661]	validation_0-map:0.80539
# [662]	validation_0-map:0.80540
# [663]	validation_0-map:0.80542
# [664]	validation_0-map:0.80542
# [665]	validation_0-map:0.80542
# [666]	validation_0-map:0.80542
# [667]	validation_0-map:0.80543
# [668]	validation_0-map:0.80544
# [669]	validation_0-map:0.80547
# [670]	validation_0-map:0.80547
# [671]	validation_0-map:0.80550
# [672]	validation_0-map:0.80551
# [673]	validation_0-map:0.80550
# [674]	validation_0-map:0.80550
# [675]	validation_0-map:0.80551
# [676]	validation_0-map:0.80552
# [677]	validation_0-map:0.80552
# [678]	validation_0-map:0.80552
# [679]	validation_0-map:0.80552
# [680]	validation_0-map:0.80553
# [681]	validation_0-map:0.80553
# [682]	validation_0-map:0.80554
# [683]	validation_0-map:0.80558
# [684]	validation_0-map:0.80558
# [685]	validation_0-map:0.80559
# [686]	validation_0-map:0.80559
# [687]	validation_0-map:0.80559
# [688]	validation_0-map:0.80561
# [689]	validation_0-map:0.80560
# [690]	validation_0-map:0.80563
# [691]	validation_0-map:0.80565
# [692]	validation_0-map:0.80566
# [693]	validation_0-map:0.80566
# [694]	validation_0-map:0.80567
# [695]	validation_0-map:0.80568
# [696]	validation_0-map:0.80568
# [697]	validation_0-map:0.80569
# [698]	validation_0-map:0.80570
# [699]	validation_0-map:0.80571
# [700]	validation_0-map:0.80571
# [701]	validation_0-map:0.80573
# [702]	validation_0-map:0.80574
# [703]	validation_0-map:0.80576
# [704]	validation_0-map:0.80576
# [705]	validation_0-map:0.80577
# [706]	validation_0-map:0.80578
# [707]	validation_0-map:0.80579
# [708]	validation_0-map:0.80581
# [709]	validation_0-map:0.80581
# [710]	validation_0-map:0.80584
# [711]	validation_0-map:0.80585
# [712]	validation_0-map:0.80584
# [713]	validation_0-map:0.80586
# [714]	validation_0-map:0.80587
# [715]	validation_0-map:0.80589
# [716]	validation_0-map:0.80588
# [717]	validation_0-map:0.80590
# [718]	validation_0-map:0.80590
# [719]	validation_0-map:0.80591
# [720]	validation_0-map:0.80592
# [721]	validation_0-map:0.80593
# [722]	validation_0-map:0.80595
# [723]	validation_0-map:0.80596
# [724]	validation_0-map:0.80596
# [725]	validation_0-map:0.80597
# [726]	validation_0-map:0.80598
# [727]	validation_0-map:0.80600
# [728]	validation_0-map:0.80601
# [729]	validation_0-map:0.80603
# [730]	validation_0-map:0.80605
# [731]	validation_0-map:0.80605
# [732]	validation_0-map:0.80606
# [733]	validation_0-map:0.80607
# [734]	validation_0-map:0.80609
# [735]	validation_0-map:0.80609
# [736]	validation_0-map:0.80612
# [737]	validation_0-map:0.80613
# [738]	validation_0-map:0.80614
# [739]	validation_0-map:0.80615
# [740]	validation_0-map:0.80616
# [741]	validation_0-map:0.80618
# [742]	validation_0-map:0.80619
# [743]	validation_0-map:0.80619
# [744]	validation_0-map:0.80621
# [745]	validation_0-map:0.80621
# [746]	validation_0-map:0.80622
# [747]	validation_0-map:0.80624
# [748]	validation_0-map:0.80626
# [749]	validation_0-map:0.80626
# [750]	validation_0-map:0.80627
# [751]	validation_0-map:0.80627
# [752]	validation_0-map:0.80627
# [753]	validation_0-map:0.80628
# [754]	validation_0-map:0.80629
# [755]	validation_0-map:0.80629
# [756]	validation_0-map:0.80631
# [757]	validation_0-map:0.80633
# [758]	validation_0-map:0.80633
# [759]	validation_0-map:0.80635
# [760]	validation_0-map:0.80636
# [761]	validation_0-map:0.80636
# [762]	validation_0-map:0.80637
# [763]	validation_0-map:0.80637
# [764]	validation_0-map:0.80636
# [765]	validation_0-map:0.80637
# [766]	validation_0-map:0.80637
# [767]	validation_0-map:0.80638
# [768]	validation_0-map:0.80638
# [769]	validation_0-map:0.80639
# [770]	validation_0-map:0.80639
# [771]	validation_0-map:0.80639
# [772]	validation_0-map:0.80640
# [773]	validation_0-map:0.80642
# [774]	validation_0-map:0.80642
# [775]	validation_0-map:0.80643
# [776]	validation_0-map:0.80642
# [777]	validation_0-map:0.80643
# [778]	validation_0-map:0.80644
# [779]	validation_0-map:0.80645
# [780]	validation_0-map:0.80646
# [781]	validation_0-map:0.80645
# [782]	validation_0-map:0.80646
# [783]	validation_0-map:0.80648
# [784]	validation_0-map:0.80649
# [785]	validation_0-map:0.80649
# [786]	validation_0-map:0.80650
# [787]	validation_0-map:0.80650
# [788]	validation_0-map:0.80651
# [789]	validation_0-map:0.80651
# [790]	validation_0-map:0.80652
# [791]	validation_0-map:0.80654
# [792]	validation_0-map:0.80654
# [793]	validation_0-map:0.80654
# [794]	validation_0-map:0.80655
# [795]	validation_0-map:0.80654
# [796]	validation_0-map:0.80656
# [797]	validation_0-map:0.80656
# [798]	validation_0-map:0.80657
# [799]	validation_0-map:0.80657
# [800]	validation_0-map:0.80658
# [801]	validation_0-map:0.80659
# [802]	validation_0-map:0.80660
# [803]	validation_0-map:0.80661
# [804]	validation_0-map:0.80664
# [805]	validation_0-map:0.80664
# [806]	validation_0-map:0.80666
# [807]	validation_0-map:0.80666
# [808]	validation_0-map:0.80668
# [809]	validation_0-map:0.80669
# [810]	validation_0-map:0.80670
# [811]	validation_0-map:0.80671
# [812]	validation_0-map:0.80671
# [813]	validation_0-map:0.80672
# [814]	validation_0-map:0.80672
# [815]	validation_0-map:0.80672
# [816]	validation_0-map:0.80672
# [817]	validation_0-map:0.80672
# [818]	validation_0-map:0.80673
# [819]	validation_0-map:0.80673
# [820]	validation_0-map:0.80674
# [821]	validation_0-map:0.80675
# [822]	validation_0-map:0.80676
# [823]	validation_0-map:0.80676
# [824]	validation_0-map:0.80676
# [825]	validation_0-map:0.80676
# [826]	validation_0-map:0.80676
# [827]	validation_0-map:0.80677
# [828]	validation_0-map:0.80677
# [829]	validation_0-map:0.80678
# [830]	validation_0-map:0.80678
# [831]	validation_0-map:0.80678
# [832]	validation_0-map:0.80678
# [833]	validation_0-map:0.80679
# [834]	validation_0-map:0.80680
# [835]	validation_0-map:0.80681
# [836]	validation_0-map:0.80681
# [837]	validation_0-map:0.80683
# [838]	validation_0-map:0.80684
# [839]	validation_0-map:0.80684
# [840]	validation_0-map:0.80685
# [841]	validation_0-map:0.80685
# [842]	validation_0-map:0.80684
# [843]	validation_0-map:0.80684
# [844]	validation_0-map:0.80684
# [845]	validation_0-map:0.80684
# [846]	validation_0-map:0.80685
# [847]	validation_0-map:0.80687
# [848]	validation_0-map:0.80687
# [849]	validation_0-map:0.80688
# [850]	validation_0-map:0.80688
# [851]	validation_0-map:0.80688
# [852]	validation_0-map:0.80689
# [853]	validation_0-map:0.80689
# [854]	validation_0-map:0.80689
# [855]	validation_0-map:0.80690
# [856]	validation_0-map:0.80690
# [857]	validation_0-map:0.80689
# [858]	validation_0-map:0.80691
# [859]	validation_0-map:0.80692
# [860]	validation_0-map:0.80695
# [861]	validation_0-map:0.80695
# [862]	validation_0-map:0.80695
# [863]	validation_0-map:0.80697
# [864]	validation_0-map:0.80698
# [865]	validation_0-map:0.80700
# [866]	validation_0-map:0.80700
# [867]	validation_0-map:0.80700
# [868]	validation_0-map:0.80701
# [869]	validation_0-map:0.80701
# [870]	validation_0-map:0.80702
# [871]	validation_0-map:0.80702
# [872]	validation_0-map:0.80703
# [873]	validation_0-map:0.80702
# [874]	validation_0-map:0.80704
# [875]	validation_0-map:0.80703
# [876]	validation_0-map:0.80705
# [877]	validation_0-map:0.80706
# [878]	validation_0-map:0.80705
# [879]	validation_0-map:0.80706
# [880]	validation_0-map:0.80707
# [881]	validation_0-map:0.80706
# [882]	validation_0-map:0.80707
# [883]	validation_0-map:0.80707
# [884]	validation_0-map:0.80710
# [885]	validation_0-map:0.80709
# [886]	validation_0-map:0.80710
# [887]	validation_0-map:0.80714
# [888]	validation_0-map:0.80714
# [889]	validation_0-map:0.80716
# [890]	validation_0-map:0.80716
# [891]	validation_0-map:0.80717
# [892]	validation_0-map:0.80719
# [893]	validation_0-map:0.80719
# [894]	validation_0-map:0.80720
# [895]	validation_0-map:0.80721
# [896]	validation_0-map:0.80721
# [897]	validation_0-map:0.80724
# [898]	validation_0-map:0.80724
# [899]	validation_0-map:0.80725
# [900]	validation_0-map:0.80725
# [901]	validation_0-map:0.80726
# [902]	validation_0-map:0.80726
# [903]	validation_0-map:0.80728
# [904]	validation_0-map:0.80728
# [905]	validation_0-map:0.80730
# [906]	validation_0-map:0.80731
# [907]	validation_0-map:0.80731
# [908]	validation_0-map:0.80731
# [909]	validation_0-map:0.80730
# [910]	validation_0-map:0.80730
# [911]	validation_0-map:0.80731
# [912]	validation_0-map:0.80732
# [913]	validation_0-map:0.80733
# [914]	validation_0-map:0.80735
# [915]	validation_0-map:0.80735
# [916]	validation_0-map:0.80735
# [917]	validation_0-map:0.80735
# [918]	validation_0-map:0.80738
# [919]	validation_0-map:0.80737
# [920]	validation_0-map:0.80738
# [921]	validation_0-map:0.80739
# [922]	validation_0-map:0.80739
# [923]	validation_0-map:0.80743
# [924]	validation_0-map:0.80744
# [925]	validation_0-map:0.80745
# [926]	validation_0-map:0.80745
# [927]	validation_0-map:0.80744
# [928]	validation_0-map:0.80747
# [929]	validation_0-map:0.80747
# [930]	validation_0-map:0.80747
# [931]	validation_0-map:0.80748
# [932]	validation_0-map:0.80749
# [933]	validation_0-map:0.80749
# [934]	validation_0-map:0.80749
# [935]	validation_0-map:0.80749
# [936]	validation_0-map:0.80750
# [937]	validation_0-map:0.80750
# [938]	validation_0-map:0.80751
# [939]	validation_0-map:0.80751
# [940]	validation_0-map:0.80752
# [941]	validation_0-map:0.80752
# [942]	validation_0-map:0.80752
# [943]	validation_0-map:0.80752
# [944]	validation_0-map:0.80753
# [945]	validation_0-map:0.80754
# [946]	validation_0-map:0.80754
# [947]	validation_0-map:0.80755
# [948]	validation_0-map:0.80755
# [949]	validation_0-map:0.80756
# [950]	validation_0-map:0.80757
# [951]	validation_0-map:0.80757
# [952]	validation_0-map:0.80758
# [953]	validation_0-map:0.80758
# [954]	validation_0-map:0.80758
# [955]	validation_0-map:0.80759
# [956]	validation_0-map:0.80759
# [957]	validation_0-map:0.80761
# [958]	validation_0-map:0.80761
# [959]	validation_0-map:0.80761
# [960]	validation_0-map:0.80761
# [961]	validation_0-map:0.80763
# [962]	validation_0-map:0.80764
# [963]	validation_0-map:0.80765
# [964]	validation_0-map:0.80765
# [965]	validation_0-map:0.80766
# [966]	validation_0-map:0.80766
# [967]	validation_0-map:0.80766
# [968]	validation_0-map:0.80767
# [969]	validation_0-map:0.80768
# [970]	validation_0-map:0.80768
# [971]	validation_0-map:0.80768
# [972]	validation_0-map:0.80768
# [973]	validation_0-map:0.80768
# [974]	validation_0-map:0.80769
# [975]	validation_0-map:0.80769
# [976]	validation_0-map:0.80769
# [977]	validation_0-map:0.80770
# [978]	validation_0-map:0.80770
# [979]	validation_0-map:0.80770
# [980]	validation_0-map:0.80770
# [981]	validation_0-map:0.80771
# [982]	validation_0-map:0.80771
# [983]	validation_0-map:0.80771
# [984]	validation_0-map:0.80772
# [985]	validation_0-map:0.80773
# [986]	validation_0-map:0.80773
# [987]	validation_0-map:0.80774
# [988]	validation_0-map:0.80775
# [989]	validation_0-map:0.80776
# [990]	validation_0-map:0.80775
# [991]	validation_0-map:0.80776
# [992]	validation_0-map:0.80776
# [993]	validation_0-map:0.80777
# [994]	validation_0-map:0.80777
# [995]	validation_0-map:0.80777
# [996]	validation_0-map:0.80777
# [997]	validation_0-map:0.80778
# [998]	validation_0-map:0.80779
# [999]	validation_0-map:0.80779
# [1000]	validation_0-map:0.80780
# [1001]	validation_0-map:0.80781
# [1002]	validation_0-map:0.80782
# [1003]	validation_0-map:0.80782
# [1004]	validation_0-map:0.80783
# [1005]	validation_0-map:0.80784
# [1006]	validation_0-map:0.80785
# [1007]	validation_0-map:0.80785
# [1008]	validation_0-map:0.80786
# [1009]	validation_0-map:0.80786
# [1010]	validation_0-map:0.80787
# [1011]	validation_0-map:0.80788
# [1012]	validation_0-map:0.80789
# [1013]	validation_0-map:0.80790
# [1014]	validation_0-map:0.80791
# [1015]	validation_0-map:0.80792
# [1016]	validation_0-map:0.80793
# [1017]	validation_0-map:0.80794
# [1018]	validation_0-map:0.80795
# [1019]	validation_0-map:0.80795
# [1020]	validation_0-map:0.80796
# [1021]	validation_0-map:0.80797
# [1022]	validation_0-map:0.80797
# [1023]	validation_0-map:0.80798
# [1024]	validation_0-map:0.80798
# [1025]	validation_0-map:0.80799
# [1026]	validation_0-map:0.80800
# [1027]	validation_0-map:0.80799
# [1028]	validation_0-map:0.80800
# [1029]	validation_0-map:0.80799
# [1030]	validation_0-map:0.80800
# [1031]	validation_0-map:0.80800
# [1032]	validation_0-map:0.80800
# [1033]	validation_0-map:0.80800
# [1034]	validation_0-map:0.80802
# [1035]	validation_0-map:0.80803
# [1036]	validation_0-map:0.80803
# [1037]	validation_0-map:0.80804
# [1038]	validation_0-map:0.80803
# [1039]	validation_0-map:0.80803
# [1040]	validation_0-map:0.80804
# [1041]	validation_0-map:0.80804
# [1042]	validation_0-map:0.80805
# [1043]	validation_0-map:0.80806
# [1044]	validation_0-map:0.80807
# [1045]	validation_0-map:0.80807
# [1046]	validation_0-map:0.80808
# [1047]	validation_0-map:0.80808
# [1048]	validation_0-map:0.80809
# [1049]	validation_0-map:0.80810
# [1050]	validation_0-map:0.80811
# [1051]	validation_0-map:0.80811
# [1052]	validation_0-map:0.80811
# [1053]	validation_0-map:0.80811
# [1054]	validation_0-map:0.80814
# [1055]	validation_0-map:0.80814
# [1056]	validation_0-map:0.80816
# [1057]	validation_0-map:0.80816
# [1058]	validation_0-map:0.80816
# [1059]	validation_0-map:0.80817
# [1060]	validation_0-map:0.80818
# [1061]	validation_0-map:0.80818
# [1062]	validation_0-map:0.80819
# [1063]	validation_0-map:0.80819
# [1064]	validation_0-map:0.80820
# [1065]	validation_0-map:0.80821
# [1066]	validation_0-map:0.80821
# [1067]	validation_0-map:0.80823
# [1068]	validation_0-map:0.80824
# [1069]	validation_0-map:0.80825
# [1070]	validation_0-map:0.80826
# [1071]	validation_0-map:0.80825
# [1072]	validation_0-map:0.80826
# [1073]	validation_0-map:0.80826
# [1074]	validation_0-map:0.80826
# [1075]	validation_0-map:0.80826
# [1076]	validation_0-map:0.80826
# [1077]	validation_0-map:0.80827
# [1078]	validation_0-map:0.80827
# [1079]	validation_0-map:0.80827
# [1080]	validation_0-map:0.80828
# [1081]	validation_0-map:0.80830
# [1082]	validation_0-map:0.80832
# [1083]	validation_0-map:0.80833
# [1084]	validation_0-map:0.80833
# [1085]	validation_0-map:0.80835
# [1086]	validation_0-map:0.80835
# [1087]	validation_0-map:0.80835
# [1088]	validation_0-map:0.80836
# [1089]	validation_0-map:0.80837
# [1090]	validation_0-map:0.80837
# [1091]	validation_0-map:0.80837
# [1092]	validation_0-map:0.80838
# [1093]	validation_0-map:0.80838
# [1094]	validation_0-map:0.80838
# [1095]	validation_0-map:0.80839
# [1096]	validation_0-map:0.80839
# [1097]	validation_0-map:0.80840
# [1098]	validation_0-map:0.80841
# [1099]	validation_0-map:0.80841
# [1100]	validation_0-map:0.80841
# [1101]	validation_0-map:0.80841
# [1102]	validation_0-map:0.80843
# [1103]	validation_0-map:0.80843
# [1104]	validation_0-map:0.80843
# [1105]	validation_0-map:0.80843
# [1106]	validation_0-map:0.80843
# [1107]	validation_0-map:0.80843
# [1108]	validation_0-map:0.80843
# [1109]	validation_0-map:0.80843
# [1110]	validation_0-map:0.80845
# [1111]	validation_0-map:0.80845
# [1112]	validation_0-map:0.80846
# [1113]	validation_0-map:0.80846
# [1114]	validation_0-map:0.80846
# [1115]	validation_0-map:0.80847
# [1116]	validation_0-map:0.80847
# [1117]	validation_0-map:0.80848
# [1118]	validation_0-map:0.80848
# [1119]	validation_0-map:0.80849
# [1120]	validation_0-map:0.80850
# [1121]	validation_0-map:0.80850
# [1122]	validation_0-map:0.80850
# [1123]	validation_0-map:0.80849
# [1124]	validation_0-map:0.80851
# [1125]	validation_0-map:0.80852
# [1126]	validation_0-map:0.80853
# [1127]	validation_0-map:0.80853
# [1128]	validation_0-map:0.80854
# [1129]	validation_0-map:0.80854
# [1130]	validation_0-map:0.80855
# [1131]	validation_0-map:0.80854
# [1132]	validation_0-map:0.80854
# [1133]	validation_0-map:0.80854
# [1134]	validation_0-map:0.80856
# [1135]	validation_0-map:0.80857
# [1136]	validation_0-map:0.80857
# [1137]	validation_0-map:0.80859
# [1138]	validation_0-map:0.80859
# [1139]	validation_0-map:0.80859
# [1140]	validation_0-map:0.80860
# [1141]	validation_0-map:0.80860
# [1142]	validation_0-map:0.80861
# [1143]	validation_0-map:0.80860
# [1144]	validation_0-map:0.80861
# [1145]	validation_0-map:0.80862
# [1146]	validation_0-map:0.80863
# [1147]	validation_0-map:0.80863
# [1148]	validation_0-map:0.80863
# [1149]	validation_0-map:0.80863
# [1150]	validation_0-map:0.80863
# [1151]	validation_0-map:0.80864
# [1152]	validation_0-map:0.80864
# [1153]	validation_0-map:0.80864
# [1154]	validation_0-map:0.80865
# [1155]	validation_0-map:0.80866
# [1156]	validation_0-map:0.80867
# [1157]	validation_0-map:0.80867
# [1158]	validation_0-map:0.80867
# [1159]	validation_0-map:0.80867
# [1160]	validation_0-map:0.80867
# [1161]	validation_0-map:0.80868
# [1162]	validation_0-map:0.80869
# [1163]	validation_0-map:0.80869
# [1164]	validation_0-map:0.80870
# [1165]	validation_0-map:0.80870
# [1166]	validation_0-map:0.80871
# [1167]	validation_0-map:0.80871
# [1168]	validation_0-map:0.80872
# [1169]	validation_0-map:0.80872
# [1170]	validation_0-map:0.80871
# [1171]	validation_0-map:0.80872
# [1172]	validation_0-map:0.80871
# [1173]	validation_0-map:0.80871
# [1174]	validation_0-map:0.80872
# [1175]	validation_0-map:0.80872
# [1176]	validation_0-map:0.80873
# [1177]	validation_0-map:0.80874
# [1178]	validation_0-map:0.80876
# [1179]	validation_0-map:0.80876
# [1180]	validation_0-map:0.80876
# [1181]	validation_0-map:0.80876
# [1182]	validation_0-map:0.80877
# [1183]	validation_0-map:0.80877
# [1184]	validation_0-map:0.80877
# [1185]	validation_0-map:0.80878
# [1186]	validation_0-map:0.80878
# [1187]	validation_0-map:0.80878
# [1188]	validation_0-map:0.80877
# [1189]	validation_0-map:0.80877
# [1190]	validation_0-map:0.80878
# [1191]	validation_0-map:0.80879
# [1192]	validation_0-map:0.80879
# [1193]	validation_0-map:0.80880
# [1194]	validation_0-map:0.80880
# [1195]	validation_0-map:0.80881
# [1196]	validation_0-map:0.80881
# [1197]	validation_0-map:0.80882
# [1198]	validation_0-map:0.80881
# [1199]	validation_0-map:0.80881
# [1200]	validation_0-map:0.80881
# [1201]	validation_0-map:0.80882
# [1202]	validation_0-map:0.80884
# [1203]	validation_0-map:0.80884
# [1204]	validation_0-map:0.80884
# [1205]	validation_0-map:0.80885
# [1206]	validation_0-map:0.80885
# [1207]	validation_0-map:0.80887
# [1208]	validation_0-map:0.80887
# [1209]	validation_0-map:0.80887
# [1210]	validation_0-map:0.80887
# [1211]	validation_0-map:0.80887
# [1212]	validation_0-map:0.80888
# [1213]	validation_0-map:0.80889
# [1214]	validation_0-map:0.80890
# [1215]	validation_0-map:0.80891
# [1216]	validation_0-map:0.80892
# [1217]	validation_0-map:0.80892
# [1218]	validation_0-map:0.80893
# [1219]	validation_0-map:0.80894
# [1220]	validation_0-map:0.80895
# [1221]	validation_0-map:0.80895
# [1222]	validation_0-map:0.80895
# [1223]	validation_0-map:0.80897
# [1224]	validation_0-map:0.80897
# [1225]	validation_0-map:0.80897
# [1226]	validation_0-map:0.80898
# [1227]	validation_0-map:0.80899
# [1228]	validation_0-map:0.80900
# [1229]	validation_0-map:0.80900
# [1230]	validation_0-map:0.80900
# [1231]	validation_0-map:0.80900
# [1232]	validation_0-map:0.80900
# [1233]	validation_0-map:0.80900
# [1234]	validation_0-map:0.80900
# [1235]	validation_0-map:0.80900
# [1236]	validation_0-map:0.80900
# [1237]	validation_0-map:0.80901
# [1238]	validation_0-map:0.80901
# [1239]	validation_0-map:0.80901
# [1240]	validation_0-map:0.80900
# [1241]	validation_0-map:0.80900
# [1242]	validation_0-map:0.80900
# [1243]	validation_0-map:0.80900
# [1244]	validation_0-map:0.80901
# [1245]	validation_0-map:0.80902
# [1246]	validation_0-map:0.80902
# [1247]	validation_0-map:0.80902
# [1248]	validation_0-map:0.80903
# [1249]	validation_0-map:0.80904
# [1250]	validation_0-map:0.80904
# [1251]	validation_0-map:0.80904
# [1252]	validation_0-map:0.80905
# [1253]	validation_0-map:0.80906
# [1254]	validation_0-map:0.80906
# [1255]	validation_0-map:0.80907
# [1256]	validation_0-map:0.80909
# [1257]	validation_0-map:0.80908
# [1258]	validation_0-map:0.80908
# [1259]	validation_0-map:0.80909
# [1260]	validation_0-map:0.80908
# [1261]	validation_0-map:0.80908
# [1262]	validation_0-map:0.80908
# [1263]	validation_0-map:0.80908
# [1264]	validation_0-map:0.80909
# [1265]	validation_0-map:0.80909
# [1266]	validation_0-map:0.80909
# [1267]	validation_0-map:0.80910
# [1268]	validation_0-map:0.80909
# [1269]	validation_0-map:0.80909
# [1270]	validation_0-map:0.80909
# [1271]	validation_0-map:0.80909
# [1272]	validation_0-map:0.80911
# [1273]	validation_0-map:0.80910
# [1274]	validation_0-map:0.80910
# [1275]	validation_0-map:0.80911
# [1276]	validation_0-map:0.80912
# [1277]	validation_0-map:0.80912
# [1278]	validation_0-map:0.80912
# [1279]	validation_0-map:0.80913
# [1280]	validation_0-map:0.80913
# [1281]	validation_0-map:0.80913
# [1282]	validation_0-map:0.80912
# [1283]	validation_0-map:0.80913
# [1284]	validation_0-map:0.80913
# [1285]	validation_0-map:0.80914
# [1286]	validation_0-map:0.80914
# [1287]	validation_0-map:0.80915
# [1288]	validation_0-map:0.80915
# [1289]	validation_0-map:0.80914
# [1290]	validation_0-map:0.80914
# [1291]	validation_0-map:0.80914
# [1292]	validation_0-map:0.80914
# [1293]	validation_0-map:0.80914
# [1294]	validation_0-map:0.80915
# [1295]	validation_0-map:0.80915
# [1296]	validation_0-map:0.80915
# [1297]	validation_0-map:0.80914
# [1298]	validation_0-map:0.80914
# [1299]	validation_0-map:0.80915
# [1300]	validation_0-map:0.80916
# [1301]	validation_0-map:0.80916
# [1302]	validation_0-map:0.80916
# [1303]	validation_0-map:0.80916
# [1304]	validation_0-map:0.80916
# [1305]	validation_0-map:0.80916
# [1306]	validation_0-map:0.80918
# [1307]	validation_0-map:0.80919
# [1308]	validation_0-map:0.80919
# [1309]	validation_0-map:0.80920
# [1310]	validation_0-map:0.80920
# [1311]	validation_0-map:0.80921
# [1312]	validation_0-map:0.80923
# [1313]	validation_0-map:0.80923
# [1314]	validation_0-map:0.80924
# [1315]	validation_0-map:0.80925
# [1316]	validation_0-map:0.80925
# [1317]	validation_0-map:0.80925
# [1318]	validation_0-map:0.80925
# [1319]	validation_0-map:0.80926
# [1320]	validation_0-map:0.80926
# [1321]	validation_0-map:0.80926
# [1322]	validation_0-map:0.80927
# [1323]	validation_0-map:0.80927
# [1324]	validation_0-map:0.80927
# [1325]	validation_0-map:0.80927
# [1326]	validation_0-map:0.80927
# [1327]	validation_0-map:0.80927
# [1328]	validation_0-map:0.80927
# [1329]	validation_0-map:0.80927
# [1330]	validation_0-map:0.80928
# [1331]	validation_0-map:0.80928
# [1332]	validation_0-map:0.80929
# [1333]	validation_0-map:0.80928
# [1334]	validation_0-map:0.80928
# [1335]	validation_0-map:0.80929
# [1336]	validation_0-map:0.80929
# [1337]	validation_0-map:0.80929
# [1338]	validation_0-map:0.80930
# [1339]	validation_0-map:0.80930
# [1340]	validation_0-map:0.80931
# [1341]	validation_0-map:0.80931
# [1342]	validation_0-map:0.80931
# [1343]	validation_0-map:0.80932
# [1344]	validation_0-map:0.80932
# [1345]	validation_0-map:0.80933
# [1346]	validation_0-map:0.80934
# [1347]	validation_0-map:0.80935
# [1348]	validation_0-map:0.80935
# [1349]	validation_0-map:0.80935
# [1350]	validation_0-map:0.80936
# [1351]	validation_0-map:0.80935
# [1352]	validation_0-map:0.80936
# [1353]	validation_0-map:0.80936
# [1354]	validation_0-map:0.80937
# [1355]	validation_0-map:0.80937
# [1356]	validation_0-map:0.80937
# [1357]	validation_0-map:0.80937
# [1358]	validation_0-map:0.80938
# [1359]	validation_0-map:0.80937
# [1360]	validation_0-map:0.80937
# [1361]	validation_0-map:0.80936
# [1362]	validation_0-map:0.80937
# [1363]	validation_0-map:0.80937
# [1364]	validation_0-map:0.80937
# [1365]	validation_0-map:0.80937
# [1366]	validation_0-map:0.80937
# [1367]	validation_0-map:0.80937
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.5,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='map', feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=5, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=5000, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
y_train_pred = model_xgboost.predict(xtrain)
y_valid_pred = model_xgboost.predict(xtest)

#print("MAP Train: {:.4f}\nMAP Valid: {:.4f}".format(confusion_matrix(ytrain, y_train_pred),
#                                                    confusion_matrix(ytest, y_valid_pred)))

# %%
cm = f1_score(ytest,y_valid_pred)
#tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
#f1 = (2*tp)/(2*tp+fp+fn)
#print(f1)
print(cm)
# Out:
# 0.7153612262676732

# %%
learning_rate_list = [0.02, 0.05, 0.1]
max_depth_list = [2, 3, 5]
n_estimators_list = [1000, 2000, 3000]

params_dict = {"learning_rate": learning_rate_list,
               "max_depth": max_depth_list,
               "n_estimators": n_estimators_list}

num_combinations = 1
for v in params_dict.values(): num_combinations *= len(v) 

print(num_combinations)
params_dict
# Out:
# 27
# {'learning_rate': [0.02, 0.05, 0.1],
#  'max_depth': [2, 3, 5],
#  'n_estimators': [1000, 2000, 3000]}

# %%
def my_f1_score(model, X, y): return f1_score(y, model.predict(X))

model_xgboost_hp = GridSearchCV(estimator=XGBClassifier(subsample=0.5,
                                                                colsample_bytree=0.25,
                                                                eval_metric='map',
                                                                use_label_encoder=False),
                                param_grid=params_dict,
                                cv=2,
                                scoring=my_f1_score,
                                return_train_score=True,
                                verbose=4)

model_xgboost_hp.fit(X, y)
# Out:
# Fitting 2 folds for each of 27 candidates, totalling 54 fits
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=1000;, score=(train=0.641, test=0.633) total time=  43.5s
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=1000;, score=(train=0.649, test=0.649) total time=  42.4s
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=2000;, score=(train=0.681, test=0.671) total time= 1.5min
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=2000;, score=(train=0.673, test=0.674) total time= 1.4min
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=3000;, score=(train=0.690, test=0.679) total time= 2.1min
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=3000;, score=(train=0.684, test=0.685) total time= 2.2min
# [CV 1/2] END learning_rate=0.02, max_depth=3, n_estimators=1000;, score=(train=0.676, test=0.667) total time=  51.3s
# [CV 2/2] END learning_rate=0.02, max_depth=3, n_estimators=1000;, score=(train=0.673, test=0.676) total time=  51.5s
# [CV 1/2] END learning_rate=0.02, max_depth=3, n_estimators=2000;, score=(train=0.694, test=0.682) total time= 1.7min
# [CV 2/2] END learning_rate=0.02, max_depth=3, n_estimators=2000;, score=(train=0.689, test=0.690) total time= 1.7min
# [CV 1/2] END learning_rate=0.02, max_depth=3, n_estimators=3000;, score=(train=0.700, test=0.687) total time= 2.6min
# [CV 2/2] END learning_rate=0.02, max_depth=3, n_estimators=3000;, score=(train=0.694, test=0.694) total time= 2.6min
# [CV 1/2] END learning_rate=0.02, max_depth=5, n_estimators=1000;, score=(train=0.699, test=0.686) total time= 1.1min
# [CV 2/2] END learning_rate=0.02, max_depth=5, n_estimators=1000;, score=(train=0.693, test=0.695) total time= 1.1min
# [CV 1/2] END learning_rate=0.02, max_depth=5, n_estimators=2000;, score=(train=0.709, test=0.694) total time= 2.2min
# [CV 2/2] END learning_rate=0.02, max_depth=5, n_estimators=2000;, score=(train=0.702, test=0.700) total time= 2.2min
# [CV 1/2] END learning_rate=0.02, max_depth=5, n_estimators=3000;, score=(train=0.713, test=0.698) total time= 3.4min
# [CV 2/2] END learning_rate=0.02, max_depth=5, n_estimators=3000;, score=(train=0.707, test=0.701) total time= 3.5min
# [CV 1/2] END learning_rate=0.05, max_depth=2, n_estimators=1000;, score=(train=0.686, test=0.675) total time=  45.7s
# [CV 2/2] END learning_rate=0.05, max_depth=2, n_estimators=1000;, score=(train=0.681, test=0.681) total time=  45.6s
# [CV 1/2] END learning_rate=0.05, max_depth=2, n_estimators=2000;, score=(train=0.695, test=0.684) total time= 1.5min
# [CV 2/2] END learning_rate=0.05, max_depth=2, n_estimators=2000;, score=(train=0.691, test=0.690) total time= 1.5min
# [CV 1/2] END learning_rate=0.05, max_depth=2, n_estimators=3000;, score=(train=0.700, test=0.688) total time= 2.3min
# [CV 2/2] END learning_rate=0.05, max_depth=2, n_estimators=3000;, score=(train=0.695, test=0.693) total time= 2.3min
# [CV 1/2] END learning_rate=0.05, max_depth=3, n_estimators=1000;, score=(train=0.697, test=0.685) total time=  53.8s
# [CV 2/2] END learning_rate=0.05, max_depth=3, n_estimators=1000;, score=(train=0.692, test=0.692) total time=  52.7s
# [CV 1/2] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=(train=0.706, test=0.692) total time= 1.7min
# [CV 2/2] END learning_rate=0.05, max_depth=3, n_estimators=2000;, score=(train=0.700, test=0.698) total time= 1.7min
# [CV 1/2] END learning_rate=0.05, max_depth=3, n_estimators=3000;, score=(train=0.709, test=0.696) total time= 2.6min
# [CV 2/2] END learning_rate=0.05, max_depth=3, n_estimators=3000;, score=(train=0.703, test=0.701) total time= 2.6min
# [CV 1/2] END learning_rate=0.05, max_depth=5, n_estimators=1000;, score=(train=0.711, test=0.696) total time= 1.1min
# [CV 2/2] END learning_rate=0.05, max_depth=5, n_estimators=1000;, score=(train=0.705, test=0.701) total time= 1.2min
# [CV 1/2] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=(train=0.718, test=0.702) total time= 2.3min
# [CV 2/2] END learning_rate=0.05, max_depth=5, n_estimators=2000;, score=(train=0.712, test=0.702) total time= 2.4min
# [CV 1/2] END learning_rate=0.05, max_depth=5, n_estimators=3000;, score=(train=0.722, test=0.705) total time= 3.4min
# [CV 2/2] END learning_rate=0.05, max_depth=5, n_estimators=3000;, score=(train=0.717, test=0.701) total time= 3.4min
# [CV 1/2] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=(train=0.695, test=0.683) total time=  45.4s
# [CV 2/2] END learning_rate=0.1, max_depth=2, n_estimators=1000;, score=(train=0.690, test=0.690) total time=  45.7s
# [CV 1/2] END learning_rate=0.1, max_depth=2, n_estimators=2000;, score=(train=0.703, test=0.690) total time= 1.6min
# [CV 2/2] END learning_rate=0.1, max_depth=2, n_estimators=2000;, score=(train=0.697, test=0.696) total time= 1.5min
# [CV 1/2] END learning_rate=0.1, max_depth=2, n_estimators=3000;, score=(train=0.707, test=0.694) total time= 2.3min
# [CV 2/2] END learning_rate=0.1, max_depth=2, n_estimators=3000;, score=(train=0.701, test=0.698) total time= 2.4min
# [CV 1/2] END learning_rate=0.1, max_depth=3, n_estimators=1000;, score=(train=0.705, test=0.693) total time=  53.0s
# [CV 2/2] END learning_rate=0.1, max_depth=3, n_estimators=1000;, score=(train=0.699, test=0.700) total time=  52.6s
# [CV 1/2] END learning_rate=0.1, max_depth=3, n_estimators=2000;, score=(train=0.712, test=0.698) total time= 1.8min
# [CV 2/2] END learning_rate=0.1, max_depth=3, n_estimators=2000;, score=(train=0.706, test=0.704) total time= 1.8min
# [CV 1/2] END learning_rate=0.1, max_depth=3, n_estimators=3000;, score=(train=0.715, test=0.701) total time= 2.6min
# [CV 2/2] END learning_rate=0.1, max_depth=3, n_estimators=3000;, score=(train=0.709, test=0.706) total time= 2.6min
# [CV 1/2] END learning_rate=0.1, max_depth=5, n_estimators=1000;, score=(train=0.718, test=0.701) total time= 1.1min
# [CV 2/2] END learning_rate=0.1, max_depth=5, n_estimators=1000;, score=(train=0.712, test=0.701) total time= 1.2min
# [CV 1/2] END learning_rate=0.1, max_depth=5, n_estimators=2000;, score=(train=0.725, test=0.705) total time= 2.3min
# [CV 2/2] END learning_rate=0.1, max_depth=5, n_estimators=2000;, score=(train=0.720, test=0.703) total time= 2.3min
# [CV 1/2] END learning_rate=0.1, max_depth=5, n_estimators=3000;, score=(train=0.730, test=0.707) total time= 3.4min
# [CV 2/2] END learning_rate=0.1, max_depth=5, n_estimators=3000;, score=(train=0.725, test=0.701) total time= 3.4min
# GridSearchCV(cv=2,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=0.25,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='map', feature_types=None,
#                                      gamma=None, gpu_id=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              param_grid={'learning_rate': [0.02, 0.05, 0.1],
#                          'max_depth': [2, 3, 5],
#                          'n_estimators': [1000, 2000, 3000]},
#              return_train_score=True,
#              scoring=<function my_f1_score at 0x0000026A41D37310>, verbose=4)

# %%
df_cv_results = pd.DataFrame(model_xgboost_hp.cv_results_)
df_cv_results = df_cv_results[['rank_test_score','mean_test_score','mean_train_score',
                               'param_learning_rate', 'param_max_depth', 'param_n_estimators']]
df_cv_results.sort_values(by='rank_test_score', inplace=True)
df_cv_results
# Out:
#     rank_test_score  mean_test_score  mean_train_score param_learning_rate  \
# 25                1         0.704338          0.722704                 0.1
# 26                2         0.704107          0.727214                 0.1
# 23                3         0.703441          0.712279                 0.1
# 17                4         0.702788          0.719586                0.05
# 16                5         0.701774          0.715282                0.05
# 22                6         0.701316          0.708960                 0.1
# 24                7         0.701130          0.714925                 0.1
# 8                 8         0.699658          0.709936                0.02
# 14                9         0.698461          0.706350                0.05
# 15               10         0.698224          0.707647                0.05
# 7                11         0.697161          0.705416                0.02
# 21               12         0.696170          0.701992                 0.1
# 20               13         0.696014          0.703611                 0.1
# 13               14         0.695216          0.702596                0.05
# 19               15         0.693105          0.700078                 0.1
# 5                16         0.690670          0.697003                0.02
# 11               17         0.690483          0.697467                0.05
# 6                18         0.690107          0.696090                0.02
# 12               19         0.688364          0.694336                0.05
# 10               20         0.686907          0.693166                0.05
# 18               21         0.686459          0.692734                 0.1
# 4                22         0.685833          0.691216                0.02
# 2                23         0.681800          0.686638                0.02
# 9                24         0.678073          0.683210                0.05
# 1                25         0.672371          0.676641                0.02
# 3                26         0.671343          0.674903                0.02
# 0                27         0.641131          0.644890                0.02
#
#    param_max_depth param_n_estimators
# 25               5               2000
# 26               5               3000
# 23               3               3000
# 17               5               3000
# 16               5               2000
# 22               3               2000
# 24               5               1000
# 8                5               3000
# 14               3               3000
# 15               5               1000
# 7                5               2000
# 21               3               1000
# 20               2               3000
# 13               3               2000
# 19               2               2000
# 5                3               3000
# 11               2               3000
# 6                5               1000
# 12               3               1000
# 10               2               2000
# 18               2               1000
# 4                3               2000
# 2                2               3000
# 9                2               1000
# 1                2               2000
# 3                3               1000
# 0                2               1000

# %%
# First sort by number of estimators as that would be x-axis
df_cv_results.sort_values(by='param_n_estimators', inplace=True)

# Find values of AUC for learning rate of 0.05 and different values of depth
lr_d2 = df_cv_results.loc[(df_cv_results['param_learning_rate']==0.05) & (df_cv_results['param_max_depth']==2),:]
lr_d3 = df_cv_results.loc[(df_cv_results['param_learning_rate']==0.05) & (df_cv_results['param_max_depth']==3),:]
lr_d5 = df_cv_results.loc[(df_cv_results['param_learning_rate']==0.05) & (df_cv_results['param_max_depth']==5),:]
lr_d7 = df_cv_results.loc[(df_cv_results['param_learning_rate']==0.05) & (df_cv_results['param_max_depth']==7),:]

# Let us plot now
fig, ax = plt.subplots(figsize=(10,5))
lr_d2.plot(x='param_n_estimators', y='mean_test_score', label='Depth=2', ax=ax)
lr_d3.plot(x='param_n_estimators', y='mean_test_score', label='Depth=3', ax=ax)
lr_d5.plot(x='param_n_estimators', y='mean_test_score', label='Depth=5', ax=ax)
lr_d7.plot(x='param_n_estimators', y='mean_test_score', label='Depth=7', ax=ax)
plt.ylabel('Mean Validation AUC')
plt.title('Performance wrt # of Trees and Depth')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23060\2473356398.py in <module>
#       9
#      10 # Let us plot now
# ---> 11 fig, ax = plt.subplots(figsize=(10,5))
#      12 lr_d2.plot(x='param_n_estimators', y='mean_test_score', label='Depth=2', ax=ax)
#      13 lr_d3.plot(x='param_n_estimators', y='mean_test_score', label='Depth=3', ax=ax)
#
# NameError: name 'plt' is not defined

# %%
# First sort by learning rate as that would be x-axis
df_cv_results.sort_values(by='param_learning_rate', inplace=True)

# Find values of AUC for learning rate of 0.05 and different values of depth
lr_t3k_d2 = df_cv_results.loc[(df_cv_results['param_n_estimators']==3000) & (df_cv_results['param_max_depth']==2),:]

# Let us plot now
fig, ax = plt.subplots(figsize=(10,5))
lr_t3k_d2.plot(x='param_learning_rate', y='mean_test_score', label='Depth=2, Trees=3000', ax=ax)
plt.ylabel('Mean Validation AUC')
plt.title('Performance wrt learning rate')

# rank_test_score	mean_test_score	mean_train_score	param_learning_rate	param_max_depth	param_n_estimators
# 1	0.704338	0.722704	0.1	5	2000

# %%
model_xgboost_fin = XGBClassifier(learning_rate=0.1,
                                          max_depth=5,
                                          n_estimators=2000,
                                          subsample=0.5,
                                          colsample_bytree=0.25,
                                          eval_metric='map',
                                          verbosity=1,
                                          use_label_encoder=False)

# Passing both training and validation dataset as we want to plot AUC for both
eval_set = [(xtrain, ytrain),(xtest, ytest)]

model_xgboost_fin.fit(xtrain,
                  ytrain,
                  early_stopping_rounds=20,
                  eval_set=eval_set,
                  verbose=True)
# Out:
# [0]	validation_0-map:0.56438	validation_1-map:0.56455
# [1]	validation_0-map:0.57185	validation_1-map:0.57259
# [2]	validation_0-map:0.57123	validation_1-map:0.57215
# [3]	validation_0-map:0.65435	validation_1-map:0.65565
# [4]	validation_0-map:0.66381	validation_1-map:0.66494
# [5]	validation_0-map:0.71127	validation_1-map:0.71217
# [6]	validation_0-map:0.73149	validation_1-map:0.73218
# [7]	validation_0-map:0.73947	validation_1-map:0.73969
# [8]	validation_0-map:0.73883	validation_1-map:0.73898
# [9]	validation_0-map:0.73612	validation_1-map:0.73633
# [10]	validation_0-map:0.73978	validation_1-map:0.73998
# [11]	validation_0-map:0.73914	validation_1-map:0.73938
# [12]	validation_0-map:0.74003	validation_1-map:0.74028
# [13]	validation_0-map:0.74094	validation_1-map:0.74116
# [14]	validation_0-map:0.74274	validation_1-map:0.74280
# [15]	validation_0-map:0.74329	validation_1-map:0.74339
# [16]	validation_0-map:0.74349	validation_1-map:0.74347
# [17]	validation_0-map:0.74666	validation_1-map:0.74659
# [18]	validation_0-map:0.74671	validation_1-map:0.74665
# [19]	validation_0-map:0.74671	validation_1-map:0.74664
# [20]	validation_0-map:0.74919	validation_1-map:0.74906
# [21]	validation_0-map:0.74904	validation_1-map:0.74887
# [22]	validation_0-map:0.74912	validation_1-map:0.74887
# [23]	validation_0-map:0.74886	validation_1-map:0.74856
# [24]	validation_0-map:0.74960	validation_1-map:0.74930
# [25]	validation_0-map:0.75303	validation_1-map:0.75262
# [26]	validation_0-map:0.75498	validation_1-map:0.75458
# [27]	validation_0-map:0.75446	validation_1-map:0.75413
# [28]	validation_0-map:0.75499	validation_1-map:0.75467
# [29]	validation_0-map:0.75504	validation_1-map:0.75476
# [30]	validation_0-map:0.75536	validation_1-map:0.75499
# [31]	validation_0-map:0.75531	validation_1-map:0.75493
# [32]	validation_0-map:0.75539	validation_1-map:0.75501
# [33]	validation_0-map:0.75521	validation_1-map:0.75478
# [34]	validation_0-map:0.75483	validation_1-map:0.75440
# [35]	validation_0-map:0.75659	validation_1-map:0.75619
# [36]	validation_0-map:0.75644	validation_1-map:0.75605
# [37]	validation_0-map:0.75628	validation_1-map:0.75592
# [38]	validation_0-map:0.75603	validation_1-map:0.75566
# [39]	validation_0-map:0.75588	validation_1-map:0.75554
# [40]	validation_0-map:0.75583	validation_1-map:0.75553
# [41]	validation_0-map:0.75674	validation_1-map:0.75652
# [42]	validation_0-map:0.75691	validation_1-map:0.75672
# [43]	validation_0-map:0.75752	validation_1-map:0.75738
# [44]	validation_0-map:0.75771	validation_1-map:0.75755
# [45]	validation_0-map:0.75761	validation_1-map:0.75742
# [46]	validation_0-map:0.75782	validation_1-map:0.75763
# [47]	validation_0-map:0.75916	validation_1-map:0.75905
# [48]	validation_0-map:0.76010	validation_1-map:0.76001
# [49]	validation_0-map:0.76119	validation_1-map:0.76123
# [50]	validation_0-map:0.76132	validation_1-map:0.76132
# [51]	validation_0-map:0.76139	validation_1-map:0.76138
# [52]	validation_0-map:0.76108	validation_1-map:0.76111
# [53]	validation_0-map:0.76244	validation_1-map:0.76242
# [54]	validation_0-map:0.76318	validation_1-map:0.76309
# [55]	validation_0-map:0.76383	validation_1-map:0.76370
# [56]	validation_0-map:0.76397	validation_1-map:0.76386
# [57]	validation_0-map:0.76404	validation_1-map:0.76394
# [58]	validation_0-map:0.76377	validation_1-map:0.76367
# [59]	validation_0-map:0.76375	validation_1-map:0.76364
# [60]	validation_0-map:0.76591	validation_1-map:0.76581
# [61]	validation_0-map:0.76622	validation_1-map:0.76610
# [62]	validation_0-map:0.76723	validation_1-map:0.76702
# [63]	validation_0-map:0.76805	validation_1-map:0.76785
# [64]	validation_0-map:0.76821	validation_1-map:0.76804
# [65]	validation_0-map:0.76874	validation_1-map:0.76861
# [66]	validation_0-map:0.76877	validation_1-map:0.76867
# [67]	validation_0-map:0.76998	validation_1-map:0.76984
# [68]	validation_0-map:0.77057	validation_1-map:0.77043
# [69]	validation_0-map:0.77060	validation_1-map:0.77045
# [70]	validation_0-map:0.77061	validation_1-map:0.77046
# [71]	validation_0-map:0.77068	validation_1-map:0.77057
# [72]	validation_0-map:0.77110	validation_1-map:0.77093
# [73]	validation_0-map:0.77103	validation_1-map:0.77087
# [74]	validation_0-map:0.77176	validation_1-map:0.77159
# [75]	validation_0-map:0.77178	validation_1-map:0.77160
# [76]	validation_0-map:0.77255	validation_1-map:0.77232
# [77]	validation_0-map:0.77284	validation_1-map:0.77263
# [78]	validation_0-map:0.77287	validation_1-map:0.77268
# [79]	validation_0-map:0.77322	validation_1-map:0.77303
# [80]	validation_0-map:0.77338	validation_1-map:0.77321
# [81]	validation_0-map:0.77358	validation_1-map:0.77341
# [82]	validation_0-map:0.77364	validation_1-map:0.77348
# [83]	validation_0-map:0.77394	validation_1-map:0.77380
# [84]	validation_0-map:0.77398	validation_1-map:0.77385
# [85]	validation_0-map:0.77476	validation_1-map:0.77464
# [86]	validation_0-map:0.77483	validation_1-map:0.77473
# [87]	validation_0-map:0.77535	validation_1-map:0.77523
# [88]	validation_0-map:0.77537	validation_1-map:0.77524
# [89]	validation_0-map:0.77537	validation_1-map:0.77526
# [90]	validation_0-map:0.77541	validation_1-map:0.77530
# [91]	validation_0-map:0.77551	validation_1-map:0.77544
# [92]	validation_0-map:0.77576	validation_1-map:0.77565
# [93]	validation_0-map:0.77575	validation_1-map:0.77563
# [94]	validation_0-map:0.77650	validation_1-map:0.77632
# [95]	validation_0-map:0.77654	validation_1-map:0.77639
# [96]	validation_0-map:0.77648	validation_1-map:0.77634
# [97]	validation_0-map:0.77677	validation_1-map:0.77662
# [98]	validation_0-map:0.77700	validation_1-map:0.77686
# [99]	validation_0-map:0.77708	validation_1-map:0.77693
# [100]	validation_0-map:0.77704	validation_1-map:0.77689
# [101]	validation_0-map:0.77745	validation_1-map:0.77731
# [102]	validation_0-map:0.77763	validation_1-map:0.77749
# [103]	validation_0-map:0.77768	validation_1-map:0.77755
# [104]	validation_0-map:0.77808	validation_1-map:0.77791
# [105]	validation_0-map:0.77805	validation_1-map:0.77788
# [106]	validation_0-map:0.77848	validation_1-map:0.77829
# [107]	validation_0-map:0.77872	validation_1-map:0.77856
# [108]	validation_0-map:0.77873	validation_1-map:0.77857
# [109]	validation_0-map:0.77876	validation_1-map:0.77859
# [110]	validation_0-map:0.77907	validation_1-map:0.77890
# [111]	validation_0-map:0.77909	validation_1-map:0.77892
# [112]	validation_0-map:0.77918	validation_1-map:0.77904
# [113]	validation_0-map:0.77942	validation_1-map:0.77927
# [114]	validation_0-map:0.77964	validation_1-map:0.77946
# [115]	validation_0-map:0.77975	validation_1-map:0.77958
# [116]	validation_0-map:0.77989	validation_1-map:0.77970
# [117]	validation_0-map:0.77990	validation_1-map:0.77971
# [118]	validation_0-map:0.78010	validation_1-map:0.77989
# [119]	validation_0-map:0.78037	validation_1-map:0.78017
# [120]	validation_0-map:0.78052	validation_1-map:0.78032
# [121]	validation_0-map:0.78053	validation_1-map:0.78033
# [122]	validation_0-map:0.78062	validation_1-map:0.78044
# [123]	validation_0-map:0.78063	validation_1-map:0.78045
# [124]	validation_0-map:0.78063	validation_1-map:0.78046
# [125]	validation_0-map:0.78089	validation_1-map:0.78071
# [126]	validation_0-map:0.78099	validation_1-map:0.78079
# [127]	validation_0-map:0.78117	validation_1-map:0.78099
# [128]	validation_0-map:0.78118	validation_1-map:0.78102
# [129]	validation_0-map:0.78117	validation_1-map:0.78101
# [130]	validation_0-map:0.78132	validation_1-map:0.78113
# [131]	validation_0-map:0.78131	validation_1-map:0.78115
# [132]	validation_0-map:0.78133	validation_1-map:0.78116
# [133]	validation_0-map:0.78159	validation_1-map:0.78138
# [134]	validation_0-map:0.78173	validation_1-map:0.78153
# [135]	validation_0-map:0.78204	validation_1-map:0.78182
# [136]	validation_0-map:0.78243	validation_1-map:0.78223
# [137]	validation_0-map:0.78263	validation_1-map:0.78240
# [138]	validation_0-map:0.78263	validation_1-map:0.78241
# [139]	validation_0-map:0.78294	validation_1-map:0.78271
# [140]	validation_0-map:0.78298	validation_1-map:0.78275
# [141]	validation_0-map:0.78324	validation_1-map:0.78298
# [142]	validation_0-map:0.78324	validation_1-map:0.78299
# [143]	validation_0-map:0.78337	validation_1-map:0.78309
# [144]	validation_0-map:0.78363	validation_1-map:0.78334
# [145]	validation_0-map:0.78407	validation_1-map:0.78377
# [146]	validation_0-map:0.78408	validation_1-map:0.78379
# [147]	validation_0-map:0.78429	validation_1-map:0.78395
# [148]	validation_0-map:0.78455	validation_1-map:0.78419
# [149]	validation_0-map:0.78456	validation_1-map:0.78420
# [150]	validation_0-map:0.78457	validation_1-map:0.78421
# [151]	validation_0-map:0.78468	validation_1-map:0.78432
# [152]	validation_0-map:0.78478	validation_1-map:0.78440
# [153]	validation_0-map:0.78497	validation_1-map:0.78460
# [154]	validation_0-map:0.78497	validation_1-map:0.78460
# [155]	validation_0-map:0.78497	validation_1-map:0.78461
# [156]	validation_0-map:0.78519	validation_1-map:0.78482
# [157]	validation_0-map:0.78523	validation_1-map:0.78484
# [158]	validation_0-map:0.78544	validation_1-map:0.78501
# [159]	validation_0-map:0.78555	validation_1-map:0.78516
# [160]	validation_0-map:0.78578	validation_1-map:0.78540
# [161]	validation_0-map:0.78592	validation_1-map:0.78553
# [162]	validation_0-map:0.78593	validation_1-map:0.78554
# [163]	validation_0-map:0.78601	validation_1-map:0.78561
# [164]	validation_0-map:0.78618	validation_1-map:0.78576
# [165]	validation_0-map:0.78638	validation_1-map:0.78596
# [166]	validation_0-map:0.78643	validation_1-map:0.78600
# [167]	validation_0-map:0.78643	validation_1-map:0.78600
# [168]	validation_0-map:0.78651	validation_1-map:0.78608
# [169]	validation_0-map:0.78658	validation_1-map:0.78617
# [170]	validation_0-map:0.78677	validation_1-map:0.78633
# [171]	validation_0-map:0.78678	validation_1-map:0.78634
# [172]	validation_0-map:0.78703	validation_1-map:0.78657
# [173]	validation_0-map:0.78720	validation_1-map:0.78671
# [174]	validation_0-map:0.78736	validation_1-map:0.78684
# [175]	validation_0-map:0.78746	validation_1-map:0.78692
# [176]	validation_0-map:0.78746	validation_1-map:0.78693
# [177]	validation_0-map:0.78747	validation_1-map:0.78693
# [178]	validation_0-map:0.78757	validation_1-map:0.78701
# [179]	validation_0-map:0.78768	validation_1-map:0.78714
# [180]	validation_0-map:0.78768	validation_1-map:0.78714
# [181]	validation_0-map:0.78768	validation_1-map:0.78714
# [182]	validation_0-map:0.78783	validation_1-map:0.78728
# [183]	validation_0-map:0.78796	validation_1-map:0.78738
# [184]	validation_0-map:0.78808	validation_1-map:0.78751
# [185]	validation_0-map:0.78808	validation_1-map:0.78751
# [186]	validation_0-map:0.78815	validation_1-map:0.78758
# [187]	validation_0-map:0.78823	validation_1-map:0.78767
# [188]	validation_0-map:0.78831	validation_1-map:0.78774
# [189]	validation_0-map:0.78848	validation_1-map:0.78789
# [190]	validation_0-map:0.78848	validation_1-map:0.78790
# [191]	validation_0-map:0.78861	validation_1-map:0.78800
# [192]	validation_0-map:0.78881	validation_1-map:0.78820
# [193]	validation_0-map:0.78898	validation_1-map:0.78836
# [194]	validation_0-map:0.78905	validation_1-map:0.78841
# [195]	validation_0-map:0.78910	validation_1-map:0.78844
# [196]	validation_0-map:0.78911	validation_1-map:0.78846
# [197]	validation_0-map:0.78923	validation_1-map:0.78857
# [198]	validation_0-map:0.78931	validation_1-map:0.78865
# [199]	validation_0-map:0.78957	validation_1-map:0.78890
# [200]	validation_0-map:0.78955	validation_1-map:0.78888
# [201]	validation_0-map:0.78956	validation_1-map:0.78888
# [202]	validation_0-map:0.78956	validation_1-map:0.78889
# [203]	validation_0-map:0.78957	validation_1-map:0.78889
# [204]	validation_0-map:0.78957	validation_1-map:0.78889
# [205]	validation_0-map:0.78961	validation_1-map:0.78893
# [206]	validation_0-map:0.78973	validation_1-map:0.78905
# [207]	validation_0-map:0.78975	validation_1-map:0.78907
# [208]	validation_0-map:0.79003	validation_1-map:0.78935
# [209]	validation_0-map:0.79025	validation_1-map:0.78956
# [210]	validation_0-map:0.79049	validation_1-map:0.78979
# [211]	validation_0-map:0.79057	validation_1-map:0.78986
# [212]	validation_0-map:0.79057	validation_1-map:0.78986
# [213]	validation_0-map:0.79073	validation_1-map:0.79001
# [214]	validation_0-map:0.79086	validation_1-map:0.79013
# [215]	validation_0-map:0.79086	validation_1-map:0.79013
# [216]	validation_0-map:0.79094	validation_1-map:0.79018
# [217]	validation_0-map:0.79105	validation_1-map:0.79028
# [218]	validation_0-map:0.79105	validation_1-map:0.79028
# [219]	validation_0-map:0.79126	validation_1-map:0.79049
# [220]	validation_0-map:0.79127	validation_1-map:0.79050
# [221]	validation_0-map:0.79134	validation_1-map:0.79056
# [222]	validation_0-map:0.79148	validation_1-map:0.79068
# [223]	validation_0-map:0.79156	validation_1-map:0.79075
# [224]	validation_0-map:0.79161	validation_1-map:0.79079
# [225]	validation_0-map:0.79161	validation_1-map:0.79079
# [226]	validation_0-map:0.79174	validation_1-map:0.79090
# [227]	validation_0-map:0.79174	validation_1-map:0.79090
# [228]	validation_0-map:0.79186	validation_1-map:0.79102
# [229]	validation_0-map:0.79190	validation_1-map:0.79104
# [230]	validation_0-map:0.79192	validation_1-map:0.79108
# [231]	validation_0-map:0.79209	validation_1-map:0.79122
# [232]	validation_0-map:0.79208	validation_1-map:0.79121
# [233]	validation_0-map:0.79210	validation_1-map:0.79123
# [234]	validation_0-map:0.79213	validation_1-map:0.79126
# [235]	validation_0-map:0.79213	validation_1-map:0.79126
# [236]	validation_0-map:0.79213	validation_1-map:0.79126
# [237]	validation_0-map:0.79223	validation_1-map:0.79136
# [238]	validation_0-map:0.79228	validation_1-map:0.79140
# [239]	validation_0-map:0.79227	validation_1-map:0.79140
# [240]	validation_0-map:0.79237	validation_1-map:0.79148
# [241]	validation_0-map:0.79237	validation_1-map:0.79148
# [242]	validation_0-map:0.79237	validation_1-map:0.79148
# [243]	validation_0-map:0.79240	validation_1-map:0.79151
# [244]	validation_0-map:0.79245	validation_1-map:0.79155
# [245]	validation_0-map:0.79248	validation_1-map:0.79157
# [246]	validation_0-map:0.79253	validation_1-map:0.79163
# [247]	validation_0-map:0.79264	validation_1-map:0.79171
# [248]	validation_0-map:0.79276	validation_1-map:0.79183
# [249]	validation_0-map:0.79276	validation_1-map:0.79183
# [250]	validation_0-map:0.79290	validation_1-map:0.79196
# [251]	validation_0-map:0.79299	validation_1-map:0.79203
# [252]	validation_0-map:0.79299	validation_1-map:0.79202
# [253]	validation_0-map:0.79300	validation_1-map:0.79203
# [254]	validation_0-map:0.79310	validation_1-map:0.79211
# [255]	validation_0-map:0.79317	validation_1-map:0.79217
# [256]	validation_0-map:0.79334	validation_1-map:0.79233
# [257]	validation_0-map:0.79336	validation_1-map:0.79237
# [258]	validation_0-map:0.79346	validation_1-map:0.79247
# [259]	validation_0-map:0.79345	validation_1-map:0.79246
# [260]	validation_0-map:0.79360	validation_1-map:0.79258
# [261]	validation_0-map:0.79363	validation_1-map:0.79260
# [262]	validation_0-map:0.79363	validation_1-map:0.79261
# [263]	validation_0-map:0.79372	validation_1-map:0.79268
# [264]	validation_0-map:0.79378	validation_1-map:0.79273
# [265]	validation_0-map:0.79378	validation_1-map:0.79273
# [266]	validation_0-map:0.79388	validation_1-map:0.79282
# [267]	validation_0-map:0.79399	validation_1-map:0.79291
# [268]	validation_0-map:0.79401	validation_1-map:0.79292
# [269]	validation_0-map:0.79403	validation_1-map:0.79295
# [270]	validation_0-map:0.79406	validation_1-map:0.79298
# [271]	validation_0-map:0.79406	validation_1-map:0.79298
# [272]	validation_0-map:0.79417	validation_1-map:0.79308
# [273]	validation_0-map:0.79424	validation_1-map:0.79313
# [274]	validation_0-map:0.79436	validation_1-map:0.79324
# [275]	validation_0-map:0.79438	validation_1-map:0.79326
# [276]	validation_0-map:0.79440	validation_1-map:0.79327
# [277]	validation_0-map:0.79446	validation_1-map:0.79332
# [278]	validation_0-map:0.79452	validation_1-map:0.79336
# [279]	validation_0-map:0.79459	validation_1-map:0.79340
# [280]	validation_0-map:0.79460	validation_1-map:0.79341
# [281]	validation_0-map:0.79470	validation_1-map:0.79348
# [282]	validation_0-map:0.79474	validation_1-map:0.79351
# [283]	validation_0-map:0.79478	validation_1-map:0.79356
# [284]	validation_0-map:0.79480	validation_1-map:0.79358
# [285]	validation_0-map:0.79491	validation_1-map:0.79368
# [286]	validation_0-map:0.79493	validation_1-map:0.79369
# [287]	validation_0-map:0.79493	validation_1-map:0.79369
# [288]	validation_0-map:0.79498	validation_1-map:0.79371
# [289]	validation_0-map:0.79507	validation_1-map:0.79379
# [290]	validation_0-map:0.79512	validation_1-map:0.79384
# [291]	validation_0-map:0.79513	validation_1-map:0.79385
# [292]	validation_0-map:0.79519	validation_1-map:0.79390
# [293]	validation_0-map:0.79521	validation_1-map:0.79392
# [294]	validation_0-map:0.79538	validation_1-map:0.79405
# [295]	validation_0-map:0.79541	validation_1-map:0.79406
# [296]	validation_0-map:0.79551	validation_1-map:0.79414
# [297]	validation_0-map:0.79556	validation_1-map:0.79418
# [298]	validation_0-map:0.79556	validation_1-map:0.79418
# [299]	validation_0-map:0.79557	validation_1-map:0.79420
# [300]	validation_0-map:0.79566	validation_1-map:0.79427
# [301]	validation_0-map:0.79573	validation_1-map:0.79432
# [302]	validation_0-map:0.79573	validation_1-map:0.79432
# [303]	validation_0-map:0.79575	validation_1-map:0.79435
# [304]	validation_0-map:0.79575	validation_1-map:0.79436
# [305]	validation_0-map:0.79577	validation_1-map:0.79437
# [306]	validation_0-map:0.79577	validation_1-map:0.79437
# [307]	validation_0-map:0.79583	validation_1-map:0.79442
# [308]	validation_0-map:0.79595	validation_1-map:0.79453
# [309]	validation_0-map:0.79602	validation_1-map:0.79460
# [310]	validation_0-map:0.79602	validation_1-map:0.79460
# [311]	validation_0-map:0.79604	validation_1-map:0.79462
# [312]	validation_0-map:0.79613	validation_1-map:0.79470
# [313]	validation_0-map:0.79617	validation_1-map:0.79474
# [314]	validation_0-map:0.79618	validation_1-map:0.79474
# [315]	validation_0-map:0.79619	validation_1-map:0.79477
# [316]	validation_0-map:0.79622	validation_1-map:0.79479
# [317]	validation_0-map:0.79622	validation_1-map:0.79480
# [318]	validation_0-map:0.79629	validation_1-map:0.79485
# [319]	validation_0-map:0.79630	validation_1-map:0.79486
# [320]	validation_0-map:0.79630	validation_1-map:0.79486
# [321]	validation_0-map:0.79630	validation_1-map:0.79486
# [322]	validation_0-map:0.79634	validation_1-map:0.79490
# [323]	validation_0-map:0.79640	validation_1-map:0.79494
# [324]	validation_0-map:0.79641	validation_1-map:0.79494
# [325]	validation_0-map:0.79651	validation_1-map:0.79503
# [326]	validation_0-map:0.79651	validation_1-map:0.79504
# [327]	validation_0-map:0.79661	validation_1-map:0.79512
# [328]	validation_0-map:0.79662	validation_1-map:0.79512
# [329]	validation_0-map:0.79664	validation_1-map:0.79514
# [330]	validation_0-map:0.79669	validation_1-map:0.79520
# [331]	validation_0-map:0.79677	validation_1-map:0.79526
# [332]	validation_0-map:0.79678	validation_1-map:0.79528
# [333]	validation_0-map:0.79688	validation_1-map:0.79536
# [334]	validation_0-map:0.79695	validation_1-map:0.79542
# [335]	validation_0-map:0.79695	validation_1-map:0.79542
# [336]	validation_0-map:0.79698	validation_1-map:0.79544
# [337]	validation_0-map:0.79704	validation_1-map:0.79549
# [338]	validation_0-map:0.79712	validation_1-map:0.79556
# [339]	validation_0-map:0.79717	validation_1-map:0.79559
# [340]	validation_0-map:0.79718	validation_1-map:0.79560
# [341]	validation_0-map:0.79718	validation_1-map:0.79560
# [342]	validation_0-map:0.79723	validation_1-map:0.79564
# [343]	validation_0-map:0.79729	validation_1-map:0.79569
# [344]	validation_0-map:0.79731	validation_1-map:0.79571
# [345]	validation_0-map:0.79733	validation_1-map:0.79573
# [346]	validation_0-map:0.79734	validation_1-map:0.79572
# [347]	validation_0-map:0.79748	validation_1-map:0.79585
# [348]	validation_0-map:0.79753	validation_1-map:0.79590
# [349]	validation_0-map:0.79761	validation_1-map:0.79597
# [350]	validation_0-map:0.79761	validation_1-map:0.79596
# [351]	validation_0-map:0.79764	validation_1-map:0.79598
# [352]	validation_0-map:0.79771	validation_1-map:0.79604
# [353]	validation_0-map:0.79774	validation_1-map:0.79605
# [354]	validation_0-map:0.79774	validation_1-map:0.79605
# [355]	validation_0-map:0.79775	validation_1-map:0.79606
# [356]	validation_0-map:0.79783	validation_1-map:0.79614
# [357]	validation_0-map:0.79791	validation_1-map:0.79619
# [358]	validation_0-map:0.79798	validation_1-map:0.79625
# [359]	validation_0-map:0.79798	validation_1-map:0.79625
# [360]	validation_0-map:0.79803	validation_1-map:0.79630
# [361]	validation_0-map:0.79805	validation_1-map:0.79632
# [362]	validation_0-map:0.79811	validation_1-map:0.79636
# [363]	validation_0-map:0.79812	validation_1-map:0.79636
# [364]	validation_0-map:0.79811	validation_1-map:0.79636
# [365]	validation_0-map:0.79820	validation_1-map:0.79645
# [366]	validation_0-map:0.79821	validation_1-map:0.79645
# [367]	validation_0-map:0.79825	validation_1-map:0.79648
# [368]	validation_0-map:0.79830	validation_1-map:0.79654
# [369]	validation_0-map:0.79830	validation_1-map:0.79654
# [370]	validation_0-map:0.79830	validation_1-map:0.79654
# [371]	validation_0-map:0.79831	validation_1-map:0.79654
# [372]	validation_0-map:0.79831	validation_1-map:0.79654
# [373]	validation_0-map:0.79839	validation_1-map:0.79659
# [374]	validation_0-map:0.79839	validation_1-map:0.79660
# [375]	validation_0-map:0.79846	validation_1-map:0.79668
# [376]	validation_0-map:0.79848	validation_1-map:0.79670
# [377]	validation_0-map:0.79848	validation_1-map:0.79670
# [378]	validation_0-map:0.79849	validation_1-map:0.79669
# [379]	validation_0-map:0.79853	validation_1-map:0.79674
# [380]	validation_0-map:0.79857	validation_1-map:0.79676
# [381]	validation_0-map:0.79861	validation_1-map:0.79681
# [382]	validation_0-map:0.79868	validation_1-map:0.79686
# [383]	validation_0-map:0.79868	validation_1-map:0.79687
# [384]	validation_0-map:0.79870	validation_1-map:0.79688
# [385]	validation_0-map:0.79877	validation_1-map:0.79693
# [386]	validation_0-map:0.79884	validation_1-map:0.79697
# [387]	validation_0-map:0.79891	validation_1-map:0.79704
# [388]	validation_0-map:0.79892	validation_1-map:0.79705
# [389]	validation_0-map:0.79898	validation_1-map:0.79709
# [390]	validation_0-map:0.79898	validation_1-map:0.79709
# [391]	validation_0-map:0.79904	validation_1-map:0.79714
# [392]	validation_0-map:0.79904	validation_1-map:0.79716
# [393]	validation_0-map:0.79916	validation_1-map:0.79728
# [394]	validation_0-map:0.79916	validation_1-map:0.79729
# [395]	validation_0-map:0.79925	validation_1-map:0.79736
# [396]	validation_0-map:0.79936	validation_1-map:0.79747
# [397]	validation_0-map:0.79937	validation_1-map:0.79747
# [398]	validation_0-map:0.79937	validation_1-map:0.79746
# [399]	validation_0-map:0.79941	validation_1-map:0.79749
# [400]	validation_0-map:0.79948	validation_1-map:0.79756
# [401]	validation_0-map:0.79951	validation_1-map:0.79761
# [402]	validation_0-map:0.79951	validation_1-map:0.79761
# [403]	validation_0-map:0.79955	validation_1-map:0.79764
# [404]	validation_0-map:0.79960	validation_1-map:0.79768
# [405]	validation_0-map:0.79967	validation_1-map:0.79774
# [406]	validation_0-map:0.79973	validation_1-map:0.79780
# [407]	validation_0-map:0.79974	validation_1-map:0.79781
# [408]	validation_0-map:0.79981	validation_1-map:0.79788
# [409]	validation_0-map:0.79982	validation_1-map:0.79789
# [410]	validation_0-map:0.79988	validation_1-map:0.79794
# [411]	validation_0-map:0.79991	validation_1-map:0.79798
# [412]	validation_0-map:0.79996	validation_1-map:0.79803
# [413]	validation_0-map:0.80003	validation_1-map:0.79809
# [414]	validation_0-map:0.80003	validation_1-map:0.79810
# [415]	validation_0-map:0.80004	validation_1-map:0.79810
# [416]	validation_0-map:0.80004	validation_1-map:0.79810
# [417]	validation_0-map:0.80009	validation_1-map:0.79813
# [418]	validation_0-map:0.80014	validation_1-map:0.79818
# [419]	validation_0-map:0.80014	validation_1-map:0.79818
# [420]	validation_0-map:0.80019	validation_1-map:0.79823
# [421]	validation_0-map:0.80021	validation_1-map:0.79826
# [422]	validation_0-map:0.80023	validation_1-map:0.79827
# [423]	validation_0-map:0.80029	validation_1-map:0.79831
# [424]	validation_0-map:0.80030	validation_1-map:0.79832
# [425]	validation_0-map:0.80037	validation_1-map:0.79838
# [426]	validation_0-map:0.80038	validation_1-map:0.79838
# [427]	validation_0-map:0.80046	validation_1-map:0.79845
# [428]	validation_0-map:0.80049	validation_1-map:0.79847
# [429]	validation_0-map:0.80049	validation_1-map:0.79847
# [430]	validation_0-map:0.80054	validation_1-map:0.79851
# [431]	validation_0-map:0.80055	validation_1-map:0.79852
# [432]	validation_0-map:0.80055	validation_1-map:0.79852
# [433]	validation_0-map:0.80059	validation_1-map:0.79855
# [434]	validation_0-map:0.80061	validation_1-map:0.79858
# [435]	validation_0-map:0.80067	validation_1-map:0.79862
# [436]	validation_0-map:0.80070	validation_1-map:0.79865
# [437]	validation_0-map:0.80071	validation_1-map:0.79866
# [438]	validation_0-map:0.80075	validation_1-map:0.79869
# [439]	validation_0-map:0.80075	validation_1-map:0.79869
# [440]	validation_0-map:0.80076	validation_1-map:0.79869
# [441]	validation_0-map:0.80082	validation_1-map:0.79873
# [442]	validation_0-map:0.80082	validation_1-map:0.79873
# [443]	validation_0-map:0.80088	validation_1-map:0.79878
# [444]	validation_0-map:0.80091	validation_1-map:0.79881
# [445]	validation_0-map:0.80092	validation_1-map:0.79882
# [446]	validation_0-map:0.80093	validation_1-map:0.79883
# [447]	validation_0-map:0.80095	validation_1-map:0.79885
# [448]	validation_0-map:0.80095	validation_1-map:0.79885
# [449]	validation_0-map:0.80098	validation_1-map:0.79887
# [450]	validation_0-map:0.80101	validation_1-map:0.79888
# [451]	validation_0-map:0.80107	validation_1-map:0.79894
# [452]	validation_0-map:0.80107	validation_1-map:0.79894
# [453]	validation_0-map:0.80112	validation_1-map:0.79899
# [454]	validation_0-map:0.80112	validation_1-map:0.79899
# [455]	validation_0-map:0.80112	validation_1-map:0.79899
# [456]	validation_0-map:0.80112	validation_1-map:0.79899
# [457]	validation_0-map:0.80116	validation_1-map:0.79903
# [458]	validation_0-map:0.80116	validation_1-map:0.79903
# [459]	validation_0-map:0.80119	validation_1-map:0.79905
# [460]	validation_0-map:0.80123	validation_1-map:0.79907
# [461]	validation_0-map:0.80123	validation_1-map:0.79908
# [462]	validation_0-map:0.80126	validation_1-map:0.79912
# [463]	validation_0-map:0.80127	validation_1-map:0.79913
# [464]	validation_0-map:0.80128	validation_1-map:0.79914
# [465]	validation_0-map:0.80132	validation_1-map:0.79917
# [466]	validation_0-map:0.80140	validation_1-map:0.79925
# [467]	validation_0-map:0.80140	validation_1-map:0.79925
# [468]	validation_0-map:0.80142	validation_1-map:0.79927
# [469]	validation_0-map:0.80142	validation_1-map:0.79927
# [470]	validation_0-map:0.80148	validation_1-map:0.79932
# [471]	validation_0-map:0.80147	validation_1-map:0.79932
# [472]	validation_0-map:0.80148	validation_1-map:0.79932
# [473]	validation_0-map:0.80148	validation_1-map:0.79933
# [474]	validation_0-map:0.80152	validation_1-map:0.79937
# [475]	validation_0-map:0.80152	validation_1-map:0.79936
# [476]	validation_0-map:0.80152	validation_1-map:0.79936
# [477]	validation_0-map:0.80154	validation_1-map:0.79938
# [478]	validation_0-map:0.80156	validation_1-map:0.79939
# [479]	validation_0-map:0.80161	validation_1-map:0.79942
# [480]	validation_0-map:0.80164	validation_1-map:0.79944
# [481]	validation_0-map:0.80171	validation_1-map:0.79952
# [482]	validation_0-map:0.80179	validation_1-map:0.79956
# [483]	validation_0-map:0.80180	validation_1-map:0.79958
# [484]	validation_0-map:0.80181	validation_1-map:0.79957
# [485]	validation_0-map:0.80182	validation_1-map:0.79958
# [486]	validation_0-map:0.80182	validation_1-map:0.79958
# [487]	validation_0-map:0.80182	validation_1-map:0.79957
# [488]	validation_0-map:0.80182	validation_1-map:0.79958
# [489]	validation_0-map:0.80189	validation_1-map:0.79963
# [490]	validation_0-map:0.80190	validation_1-map:0.79963
# [491]	validation_0-map:0.80190	validation_1-map:0.79964
# [492]	validation_0-map:0.80195	validation_1-map:0.79967
# [493]	validation_0-map:0.80196	validation_1-map:0.79967
# [494]	validation_0-map:0.80196	validation_1-map:0.79967
# [495]	validation_0-map:0.80198	validation_1-map:0.79968
# [496]	validation_0-map:0.80200	validation_1-map:0.79970
# [497]	validation_0-map:0.80205	validation_1-map:0.79974
# [498]	validation_0-map:0.80205	validation_1-map:0.79974
# [499]	validation_0-map:0.80206	validation_1-map:0.79974
# [500]	validation_0-map:0.80208	validation_1-map:0.79975
# [501]	validation_0-map:0.80219	validation_1-map:0.79985
# [502]	validation_0-map:0.80219	validation_1-map:0.79985
# [503]	validation_0-map:0.80219	validation_1-map:0.79984
# [504]	validation_0-map:0.80221	validation_1-map:0.79986
# [505]	validation_0-map:0.80223	validation_1-map:0.79987
# [506]	validation_0-map:0.80229	validation_1-map:0.79993
# [507]	validation_0-map:0.80229	validation_1-map:0.79992
# [508]	validation_0-map:0.80229	validation_1-map:0.79992
# [509]	validation_0-map:0.80229	validation_1-map:0.79992
# [510]	validation_0-map:0.80228	validation_1-map:0.79991
# [511]	validation_0-map:0.80229	validation_1-map:0.79992
# [512]	validation_0-map:0.80229	validation_1-map:0.79992
# [513]	validation_0-map:0.80235	validation_1-map:0.79997
# [514]	validation_0-map:0.80243	validation_1-map:0.80005
# [515]	validation_0-map:0.80248	validation_1-map:0.80010
# [516]	validation_0-map:0.80250	validation_1-map:0.80012
# [517]	validation_0-map:0.80250	validation_1-map:0.80012
# [518]	validation_0-map:0.80252	validation_1-map:0.80013
# [519]	validation_0-map:0.80252	validation_1-map:0.80013
# [520]	validation_0-map:0.80253	validation_1-map:0.80013
# [521]	validation_0-map:0.80253	validation_1-map:0.80013
# [522]	validation_0-map:0.80258	validation_1-map:0.80017
# [523]	validation_0-map:0.80258	validation_1-map:0.80017
# [524]	validation_0-map:0.80263	validation_1-map:0.80019
# [525]	validation_0-map:0.80266	validation_1-map:0.80023
# [526]	validation_0-map:0.80271	validation_1-map:0.80026
# [527]	validation_0-map:0.80273	validation_1-map:0.80028
# [528]	validation_0-map:0.80273	validation_1-map:0.80028
# [529]	validation_0-map:0.80275	validation_1-map:0.80029
# [530]	validation_0-map:0.80279	validation_1-map:0.80031
# [531]	validation_0-map:0.80279	validation_1-map:0.80032
# [532]	validation_0-map:0.80279	validation_1-map:0.80032
# [533]	validation_0-map:0.80280	validation_1-map:0.80032
# [534]	validation_0-map:0.80280	validation_1-map:0.80032
# [535]	validation_0-map:0.80284	validation_1-map:0.80035
# [536]	validation_0-map:0.80285	validation_1-map:0.80036
# [537]	validation_0-map:0.80289	validation_1-map:0.80039
# [538]	validation_0-map:0.80289	validation_1-map:0.80038
# [539]	validation_0-map:0.80290	validation_1-map:0.80040
# [540]	validation_0-map:0.80294	validation_1-map:0.80042
# [541]	validation_0-map:0.80301	validation_1-map:0.80048
# [542]	validation_0-map:0.80301	validation_1-map:0.80047
# [543]	validation_0-map:0.80301	validation_1-map:0.80047
# [544]	validation_0-map:0.80302	validation_1-map:0.80048
# [545]	validation_0-map:0.80302	validation_1-map:0.80048
# [546]	validation_0-map:0.80302	validation_1-map:0.80047
# [547]	validation_0-map:0.80307	validation_1-map:0.80053
# [548]	validation_0-map:0.80308	validation_1-map:0.80053
# [549]	validation_0-map:0.80309	validation_1-map:0.80054
# [550]	validation_0-map:0.80313	validation_1-map:0.80057
# [551]	validation_0-map:0.80313	validation_1-map:0.80057
# [552]	validation_0-map:0.80313	validation_1-map:0.80057
# [553]	validation_0-map:0.80313	validation_1-map:0.80057
# [554]	validation_0-map:0.80314	validation_1-map:0.80057
# [555]	validation_0-map:0.80320	validation_1-map:0.80063
# [556]	validation_0-map:0.80320	validation_1-map:0.80063
# [557]	validation_0-map:0.80321	validation_1-map:0.80064
# [558]	validation_0-map:0.80321	validation_1-map:0.80064
# [559]	validation_0-map:0.80326	validation_1-map:0.80067
# [560]	validation_0-map:0.80328	validation_1-map:0.80067
# [561]	validation_0-map:0.80331	validation_1-map:0.80070
# [562]	validation_0-map:0.80331	validation_1-map:0.80069
# [563]	validation_0-map:0.80331	validation_1-map:0.80069
# [564]	validation_0-map:0.80336	validation_1-map:0.80075
# [565]	validation_0-map:0.80339	validation_1-map:0.80079
# [566]	validation_0-map:0.80339	validation_1-map:0.80079
# [567]	validation_0-map:0.80341	validation_1-map:0.80080
# [568]	validation_0-map:0.80341	validation_1-map:0.80081
# [569]	validation_0-map:0.80342	validation_1-map:0.80081
# [570]	validation_0-map:0.80342	validation_1-map:0.80082
# [571]	validation_0-map:0.80343	validation_1-map:0.80082
# [572]	validation_0-map:0.80348	validation_1-map:0.80087
# [573]	validation_0-map:0.80354	validation_1-map:0.80091
# [574]	validation_0-map:0.80355	validation_1-map:0.80091
# [575]	validation_0-map:0.80356	validation_1-map:0.80092
# [576]	validation_0-map:0.80357	validation_1-map:0.80093
# [577]	validation_0-map:0.80356	validation_1-map:0.80093
# [578]	validation_0-map:0.80359	validation_1-map:0.80095
# [579]	validation_0-map:0.80363	validation_1-map:0.80098
# [580]	validation_0-map:0.80368	validation_1-map:0.80102
# [581]	validation_0-map:0.80373	validation_1-map:0.80105
# [582]	validation_0-map:0.80373	validation_1-map:0.80105
# [583]	validation_0-map:0.80373	validation_1-map:0.80105
# [584]	validation_0-map:0.80376	validation_1-map:0.80107
# [585]	validation_0-map:0.80378	validation_1-map:0.80108
# [586]	validation_0-map:0.80378	validation_1-map:0.80108
# [587]	validation_0-map:0.80378	validation_1-map:0.80108
# [588]	validation_0-map:0.80382	validation_1-map:0.80110
# [589]	validation_0-map:0.80382	validation_1-map:0.80110
# [590]	validation_0-map:0.80386	validation_1-map:0.80112
# [591]	validation_0-map:0.80390	validation_1-map:0.80117
# [592]	validation_0-map:0.80395	validation_1-map:0.80120
# [593]	validation_0-map:0.80397	validation_1-map:0.80121
# [594]	validation_0-map:0.80397	validation_1-map:0.80121
# [595]	validation_0-map:0.80403	validation_1-map:0.80127
# [596]	validation_0-map:0.80406	validation_1-map:0.80130
# [597]	validation_0-map:0.80407	validation_1-map:0.80130
# [598]	validation_0-map:0.80408	validation_1-map:0.80131
# [599]	validation_0-map:0.80410	validation_1-map:0.80132
# [600]	validation_0-map:0.80412	validation_1-map:0.80135
# [601]	validation_0-map:0.80414	validation_1-map:0.80137
# [602]	validation_0-map:0.80417	validation_1-map:0.80139
# [603]	validation_0-map:0.80422	validation_1-map:0.80141
# [604]	validation_0-map:0.80426	validation_1-map:0.80145
# [605]	validation_0-map:0.80425	validation_1-map:0.80143
# [606]	validation_0-map:0.80426	validation_1-map:0.80144
# [607]	validation_0-map:0.80430	validation_1-map:0.80148
# [608]	validation_0-map:0.80432	validation_1-map:0.80150
# [609]	validation_0-map:0.80436	validation_1-map:0.80154
# [610]	validation_0-map:0.80440	validation_1-map:0.80158
# [611]	validation_0-map:0.80448	validation_1-map:0.80165
# [612]	validation_0-map:0.80448	validation_1-map:0.80165
# [613]	validation_0-map:0.80451	validation_1-map:0.80169
# [614]	validation_0-map:0.80455	validation_1-map:0.80171
# [615]	validation_0-map:0.80457	validation_1-map:0.80173
# [616]	validation_0-map:0.80458	validation_1-map:0.80173
# [617]	validation_0-map:0.80458	validation_1-map:0.80173
# [618]	validation_0-map:0.80465	validation_1-map:0.80179
# [619]	validation_0-map:0.80466	validation_1-map:0.80179
# [620]	validation_0-map:0.80468	validation_1-map:0.80181
# [621]	validation_0-map:0.80468	validation_1-map:0.80181
# [622]	validation_0-map:0.80470	validation_1-map:0.80181
# [623]	validation_0-map:0.80472	validation_1-map:0.80182
# [624]	validation_0-map:0.80473	validation_1-map:0.80182
# [625]	validation_0-map:0.80474	validation_1-map:0.80181
# [626]	validation_0-map:0.80476	validation_1-map:0.80184
# [627]	validation_0-map:0.80477	validation_1-map:0.80184
# [628]	validation_0-map:0.80479	validation_1-map:0.80185
# [629]	validation_0-map:0.80482	validation_1-map:0.80187
# [630]	validation_0-map:0.80482	validation_1-map:0.80187
# [631]	validation_0-map:0.80482	validation_1-map:0.80187
# [632]	validation_0-map:0.80482	validation_1-map:0.80188
# [633]	validation_0-map:0.80484	validation_1-map:0.80188
# [634]	validation_0-map:0.80490	validation_1-map:0.80193
# [635]	validation_0-map:0.80491	validation_1-map:0.80193
# [636]	validation_0-map:0.80495	validation_1-map:0.80195
# [637]	validation_0-map:0.80497	validation_1-map:0.80198
# [638]	validation_0-map:0.80497	validation_1-map:0.80198
# [639]	validation_0-map:0.80497	validation_1-map:0.80198
# [640]	validation_0-map:0.80499	validation_1-map:0.80199
# [641]	validation_0-map:0.80502	validation_1-map:0.80201
# [642]	validation_0-map:0.80504	validation_1-map:0.80203
# [643]	validation_0-map:0.80504	validation_1-map:0.80203
# [644]	validation_0-map:0.80508	validation_1-map:0.80205
# [645]	validation_0-map:0.80512	validation_1-map:0.80209
# [646]	validation_0-map:0.80515	validation_1-map:0.80211
# [647]	validation_0-map:0.80515	validation_1-map:0.80211
# [648]	validation_0-map:0.80519	validation_1-map:0.80214
# [649]	validation_0-map:0.80524	validation_1-map:0.80217
# [650]	validation_0-map:0.80526	validation_1-map:0.80218
# [651]	validation_0-map:0.80529	validation_1-map:0.80220
# [652]	validation_0-map:0.80528	validation_1-map:0.80220
# [653]	validation_0-map:0.80529	validation_1-map:0.80221
# [654]	validation_0-map:0.80530	validation_1-map:0.80221
# [655]	validation_0-map:0.80534	validation_1-map:0.80224
# [656]	validation_0-map:0.80537	validation_1-map:0.80227
# [657]	validation_0-map:0.80537	validation_1-map:0.80227
# [658]	validation_0-map:0.80541	validation_1-map:0.80230
# [659]	validation_0-map:0.80543	validation_1-map:0.80232
# [660]	validation_0-map:0.80546	validation_1-map:0.80233
# [661]	validation_0-map:0.80547	validation_1-map:0.80233
# [662]	validation_0-map:0.80550	validation_1-map:0.80236
# [663]	validation_0-map:0.80557	validation_1-map:0.80242
# [664]	validation_0-map:0.80558	validation_1-map:0.80242
# [665]	validation_0-map:0.80560	validation_1-map:0.80244
# [666]	validation_0-map:0.80560	validation_1-map:0.80244
# [667]	validation_0-map:0.80562	validation_1-map:0.80245
# [668]	validation_0-map:0.80562	validation_1-map:0.80245
# [669]	validation_0-map:0.80564	validation_1-map:0.80247
# [670]	validation_0-map:0.80566	validation_1-map:0.80246
# [671]	validation_0-map:0.80566	validation_1-map:0.80246
# [672]	validation_0-map:0.80567	validation_1-map:0.80246
# [673]	validation_0-map:0.80567	validation_1-map:0.80246
# [674]	validation_0-map:0.80569	validation_1-map:0.80247
# [675]	validation_0-map:0.80570	validation_1-map:0.80248
# [676]	validation_0-map:0.80572	validation_1-map:0.80248
# [677]	validation_0-map:0.80575	validation_1-map:0.80250
# [678]	validation_0-map:0.80575	validation_1-map:0.80249
# [679]	validation_0-map:0.80576	validation_1-map:0.80251
# [680]	validation_0-map:0.80579	validation_1-map:0.80251
# [681]	validation_0-map:0.80579	validation_1-map:0.80251
# [682]	validation_0-map:0.80580	validation_1-map:0.80252
# [683]	validation_0-map:0.80584	validation_1-map:0.80255
# [684]	validation_0-map:0.80585	validation_1-map:0.80255
# [685]	validation_0-map:0.80586	validation_1-map:0.80256
# [686]	validation_0-map:0.80588	validation_1-map:0.80258
# [687]	validation_0-map:0.80591	validation_1-map:0.80260
# [688]	validation_0-map:0.80592	validation_1-map:0.80261
# [689]	validation_0-map:0.80593	validation_1-map:0.80261
# [690]	validation_0-map:0.80594	validation_1-map:0.80262
# [691]	validation_0-map:0.80594	validation_1-map:0.80262
# [692]	validation_0-map:0.80596	validation_1-map:0.80263
# [693]	validation_0-map:0.80599	validation_1-map:0.80265
# [694]	validation_0-map:0.80599	validation_1-map:0.80266
# [695]	validation_0-map:0.80599	validation_1-map:0.80265
# [696]	validation_0-map:0.80601	validation_1-map:0.80266
# [697]	validation_0-map:0.80602	validation_1-map:0.80267
# [698]	validation_0-map:0.80604	validation_1-map:0.80268
# [699]	validation_0-map:0.80607	validation_1-map:0.80270
# [700]	validation_0-map:0.80608	validation_1-map:0.80271
# [701]	validation_0-map:0.80608	validation_1-map:0.80271
# [702]	validation_0-map:0.80613	validation_1-map:0.80277
# [703]	validation_0-map:0.80613	validation_1-map:0.80277
# [704]	validation_0-map:0.80615	validation_1-map:0.80278
# [705]	validation_0-map:0.80617	validation_1-map:0.80280
# [706]	validation_0-map:0.80620	validation_1-map:0.80282
# [707]	validation_0-map:0.80622	validation_1-map:0.80284
# [708]	validation_0-map:0.80626	validation_1-map:0.80288
# [709]	validation_0-map:0.80628	validation_1-map:0.80289
# [710]	validation_0-map:0.80633	validation_1-map:0.80294
# [711]	validation_0-map:0.80634	validation_1-map:0.80294
# [712]	validation_0-map:0.80634	validation_1-map:0.80294
# [713]	validation_0-map:0.80636	validation_1-map:0.80295
# [714]	validation_0-map:0.80638	validation_1-map:0.80297
# [715]	validation_0-map:0.80640	validation_1-map:0.80299
# [716]	validation_0-map:0.80640	validation_1-map:0.80298
# [717]	validation_0-map:0.80646	validation_1-map:0.80302
# [718]	validation_0-map:0.80647	validation_1-map:0.80303
# [719]	validation_0-map:0.80647	validation_1-map:0.80303
# [720]	validation_0-map:0.80647	validation_1-map:0.80303
# [721]	validation_0-map:0.80648	validation_1-map:0.80303
# [722]	validation_0-map:0.80648	validation_1-map:0.80303
# [723]	validation_0-map:0.80648	validation_1-map:0.80302
# [724]	validation_0-map:0.80648	validation_1-map:0.80302
# [725]	validation_0-map:0.80649	validation_1-map:0.80302
# [726]	validation_0-map:0.80651	validation_1-map:0.80304
# [727]	validation_0-map:0.80651	validation_1-map:0.80304
# [728]	validation_0-map:0.80652	validation_1-map:0.80305
# [729]	validation_0-map:0.80656	validation_1-map:0.80309
# [730]	validation_0-map:0.80656	validation_1-map:0.80309
# [731]	validation_0-map:0.80657	validation_1-map:0.80309
# [732]	validation_0-map:0.80657	validation_1-map:0.80308
# [733]	validation_0-map:0.80661	validation_1-map:0.80311
# [734]	validation_0-map:0.80661	validation_1-map:0.80311
# [735]	validation_0-map:0.80661	validation_1-map:0.80311
# [736]	validation_0-map:0.80662	validation_1-map:0.80312
# [737]	validation_0-map:0.80663	validation_1-map:0.80312
# [738]	validation_0-map:0.80662	validation_1-map:0.80311
# [739]	validation_0-map:0.80667	validation_1-map:0.80316
# [740]	validation_0-map:0.80667	validation_1-map:0.80316
# [741]	validation_0-map:0.80667	validation_1-map:0.80316
# [742]	validation_0-map:0.80668	validation_1-map:0.80316
# [743]	validation_0-map:0.80670	validation_1-map:0.80319
# [744]	validation_0-map:0.80670	validation_1-map:0.80319
# [745]	validation_0-map:0.80670	validation_1-map:0.80319
# [746]	validation_0-map:0.80675	validation_1-map:0.80323
# [747]	validation_0-map:0.80677	validation_1-map:0.80325
# [748]	validation_0-map:0.80682	validation_1-map:0.80327
# [749]	validation_0-map:0.80682	validation_1-map:0.80327
# [750]	validation_0-map:0.80682	validation_1-map:0.80328
# [751]	validation_0-map:0.80685	validation_1-map:0.80329
# [752]	validation_0-map:0.80686	validation_1-map:0.80329
# [753]	validation_0-map:0.80687	validation_1-map:0.80330
# [754]	validation_0-map:0.80687	validation_1-map:0.80330
# [755]	validation_0-map:0.80689	validation_1-map:0.80331
# [756]	validation_0-map:0.80689	validation_1-map:0.80331
# [757]	validation_0-map:0.80692	validation_1-map:0.80335
# [758]	validation_0-map:0.80693	validation_1-map:0.80335
# [759]	validation_0-map:0.80696	validation_1-map:0.80337
# [760]	validation_0-map:0.80697	validation_1-map:0.80337
# [761]	validation_0-map:0.80697	validation_1-map:0.80337
# [762]	validation_0-map:0.80698	validation_1-map:0.80338
# [763]	validation_0-map:0.80699	validation_1-map:0.80339
# [764]	validation_0-map:0.80701	validation_1-map:0.80340
# [765]	validation_0-map:0.80703	validation_1-map:0.80342
# [766]	validation_0-map:0.80703	validation_1-map:0.80343
# [767]	validation_0-map:0.80705	validation_1-map:0.80343
# [768]	validation_0-map:0.80705	validation_1-map:0.80343
# [769]	validation_0-map:0.80708	validation_1-map:0.80346
# [770]	validation_0-map:0.80711	validation_1-map:0.80348
# [771]	validation_0-map:0.80712	validation_1-map:0.80349
# [772]	validation_0-map:0.80714	validation_1-map:0.80351
# [773]	validation_0-map:0.80718	validation_1-map:0.80353
# [774]	validation_0-map:0.80718	validation_1-map:0.80353
# [775]	validation_0-map:0.80718	validation_1-map:0.80352
# [776]	validation_0-map:0.80718	validation_1-map:0.80352
# [777]	validation_0-map:0.80719	validation_1-map:0.80353
# [778]	validation_0-map:0.80721	validation_1-map:0.80354
# [779]	validation_0-map:0.80721	validation_1-map:0.80353
# [780]	validation_0-map:0.80722	validation_1-map:0.80354
# [781]	validation_0-map:0.80722	validation_1-map:0.80354
# [782]	validation_0-map:0.80722	validation_1-map:0.80354
# [783]	validation_0-map:0.80724	validation_1-map:0.80355
# [784]	validation_0-map:0.80726	validation_1-map:0.80357
# [785]	validation_0-map:0.80725	validation_1-map:0.80357
# [786]	validation_0-map:0.80729	validation_1-map:0.80359
# [787]	validation_0-map:0.80732	validation_1-map:0.80360
# [788]	validation_0-map:0.80732	validation_1-map:0.80360
# [789]	validation_0-map:0.80735	validation_1-map:0.80363
# [790]	validation_0-map:0.80737	validation_1-map:0.80364
# [791]	validation_0-map:0.80737	validation_1-map:0.80364
# [792]	validation_0-map:0.80738	validation_1-map:0.80366
# [793]	validation_0-map:0.80738	validation_1-map:0.80366
# [794]	validation_0-map:0.80738	validation_1-map:0.80366
# [795]	validation_0-map:0.80739	validation_1-map:0.80366
# [796]	validation_0-map:0.80743	validation_1-map:0.80369
# [797]	validation_0-map:0.80744	validation_1-map:0.80369
# [798]	validation_0-map:0.80746	validation_1-map:0.80370
# [799]	validation_0-map:0.80746	validation_1-map:0.80370
# [800]	validation_0-map:0.80749	validation_1-map:0.80372
# [801]	validation_0-map:0.80752	validation_1-map:0.80376
# [802]	validation_0-map:0.80752	validation_1-map:0.80375
# [803]	validation_0-map:0.80752	validation_1-map:0.80375
# [804]	validation_0-map:0.80753	validation_1-map:0.80376
# [805]	validation_0-map:0.80753	validation_1-map:0.80376
# [806]	validation_0-map:0.80756	validation_1-map:0.80377
# [807]	validation_0-map:0.80757	validation_1-map:0.80379
# [808]	validation_0-map:0.80759	validation_1-map:0.80379
# [809]	validation_0-map:0.80761	validation_1-map:0.80381
# [810]	validation_0-map:0.80761	validation_1-map:0.80381
# [811]	validation_0-map:0.80763	validation_1-map:0.80382
# [812]	validation_0-map:0.80765	validation_1-map:0.80383
# [813]	validation_0-map:0.80767	validation_1-map:0.80385
# [814]	validation_0-map:0.80767	validation_1-map:0.80385
# [815]	validation_0-map:0.80769	validation_1-map:0.80388
# [816]	validation_0-map:0.80774	validation_1-map:0.80391
# [817]	validation_0-map:0.80775	validation_1-map:0.80392
# [818]	validation_0-map:0.80776	validation_1-map:0.80393
# [819]	validation_0-map:0.80776	validation_1-map:0.80392
# [820]	validation_0-map:0.80776	validation_1-map:0.80392
# [821]	validation_0-map:0.80777	validation_1-map:0.80394
# [822]	validation_0-map:0.80779	validation_1-map:0.80396
# [823]	validation_0-map:0.80779	validation_1-map:0.80396
# [824]	validation_0-map:0.80781	validation_1-map:0.80398
# [825]	validation_0-map:0.80782	validation_1-map:0.80400
# [826]	validation_0-map:0.80784	validation_1-map:0.80402
# [827]	validation_0-map:0.80784	validation_1-map:0.80401
# [828]	validation_0-map:0.80785	validation_1-map:0.80402
# [829]	validation_0-map:0.80785	validation_1-map:0.80402
# [830]	validation_0-map:0.80786	validation_1-map:0.80402
# [831]	validation_0-map:0.80788	validation_1-map:0.80403
# [832]	validation_0-map:0.80791	validation_1-map:0.80405
# [833]	validation_0-map:0.80791	validation_1-map:0.80405
# [834]	validation_0-map:0.80791	validation_1-map:0.80405
# [835]	validation_0-map:0.80794	validation_1-map:0.80408
# [836]	validation_0-map:0.80797	validation_1-map:0.80411
# [837]	validation_0-map:0.80799	validation_1-map:0.80414
# [838]	validation_0-map:0.80799	validation_1-map:0.80414
# [839]	validation_0-map:0.80800	validation_1-map:0.80414
# [840]	validation_0-map:0.80800	validation_1-map:0.80415
# [841]	validation_0-map:0.80801	validation_1-map:0.80415
# [842]	validation_0-map:0.80802	validation_1-map:0.80415
# [843]	validation_0-map:0.80802	validation_1-map:0.80415
# [844]	validation_0-map:0.80802	validation_1-map:0.80416
# [845]	validation_0-map:0.80802	validation_1-map:0.80415
# [846]	validation_0-map:0.80803	validation_1-map:0.80416
# [847]	validation_0-map:0.80804	validation_1-map:0.80416
# [848]	validation_0-map:0.80804	validation_1-map:0.80415
# [849]	validation_0-map:0.80804	validation_1-map:0.80415
# [850]	validation_0-map:0.80805	validation_1-map:0.80415
# [851]	validation_0-map:0.80806	validation_1-map:0.80416
# [852]	validation_0-map:0.80806	validation_1-map:0.80417
# [853]	validation_0-map:0.80806	validation_1-map:0.80417
# [854]	validation_0-map:0.80806	validation_1-map:0.80417
# [855]	validation_0-map:0.80808	validation_1-map:0.80418
# [856]	validation_0-map:0.80809	validation_1-map:0.80418
# [857]	validation_0-map:0.80810	validation_1-map:0.80418
# [858]	validation_0-map:0.80811	validation_1-map:0.80420
# ...
# [1732]	validation_0-map:0.81508	validation_1-map:0.80817
# [1733]	validation_0-map:0.81510	validation_1-map:0.80818
# [1734]	validation_0-map:0.81512	validation_1-map:0.80820
# [1735]	validation_0-map:0.81514	validation_1-map:0.80822
# [1736]	validation_0-map:0.81514	validation_1-map:0.80821
# [1737]	validation_0-map:0.81514	validation_1-map:0.80820
# [1738]	validation_0-map:0.81514	validation_1-map:0.80821
# [1739]	validation_0-map:0.81515	validation_1-map:0.80821
# [1740]	validation_0-map:0.81516	validation_1-map:0.80821
# [1741]	validation_0-map:0.81516	validation_1-map:0.80821
# [1742]	validation_0-map:0.81516	validation_1-map:0.80821
# [1743]	validation_0-map:0.81518	validation_1-map:0.80822
# [1744]	validation_0-map:0.81519	validation_1-map:0.80822
# [1745]	validation_0-map:0.81519	validation_1-map:0.80822
# [1746]	validation_0-map:0.81521	validation_1-map:0.80823
# [1747]	validation_0-map:0.81521	validation_1-map:0.80823
# [1748]	validation_0-map:0.81521	validation_1-map:0.80823
# [1749]	validation_0-map:0.81522	validation_1-map:0.80823
# [1750]	validation_0-map:0.81524	validation_1-map:0.80825
# [1751]	validation_0-map:0.81525	validation_1-map:0.80825
# [1752]	validation_0-map:0.81525	validation_1-map:0.80825
# [1753]	validation_0-map:0.81525	validation_1-map:0.80825
# [1754]	validation_0-map:0.81525	validation_1-map:0.80826
# [1755]	validation_0-map:0.81525	validation_1-map:0.80825
# [1756]	validation_0-map:0.81526	validation_1-map:0.80826
# [1757]	validation_0-map:0.81529	validation_1-map:0.80827
# [1758]	validation_0-map:0.81531	validation_1-map:0.80829
# [1759]	validation_0-map:0.81531	validation_1-map:0.80829
# [1760]	validation_0-map:0.81532	validation_1-map:0.80830
# [1761]	validation_0-map:0.81532	validation_1-map:0.80830
# [1762]	validation_0-map:0.81532	validation_1-map:0.80830
# [1763]	validation_0-map:0.81532	validation_1-map:0.80830
# [1764]	validation_0-map:0.81533	validation_1-map:0.80830
# [1765]	validation_0-map:0.81532	validation_1-map:0.80830
# [1766]	validation_0-map:0.81533	validation_1-map:0.80829
# [1767]	validation_0-map:0.81535	validation_1-map:0.80831
# [1768]	validation_0-map:0.81535	validation_1-map:0.80831
# [1769]	validation_0-map:0.81536	validation_1-map:0.80831
# [1770]	validation_0-map:0.81536	validation_1-map:0.80831
# [1771]	validation_0-map:0.81537	validation_1-map:0.80831
# [1772]	validation_0-map:0.81537	validation_1-map:0.80831
# [1773]	validation_0-map:0.81538	validation_1-map:0.80832
# [1774]	validation_0-map:0.81538	validation_1-map:0.80832
# [1775]	validation_0-map:0.81538	validation_1-map:0.80832
# [1776]	validation_0-map:0.81539	validation_1-map:0.80832
# [1777]	validation_0-map:0.81539	validation_1-map:0.80832
# [1778]	validation_0-map:0.81540	validation_1-map:0.80832
# [1779]	validation_0-map:0.81541	validation_1-map:0.80833
# [1780]	validation_0-map:0.81542	validation_1-map:0.80832
# [1781]	validation_0-map:0.81544	validation_1-map:0.80833
# [1782]	validation_0-map:0.81544	validation_1-map:0.80834
# [1783]	validation_0-map:0.81545	validation_1-map:0.80834
# [1784]	validation_0-map:0.81546	validation_1-map:0.80834
# [1785]	validation_0-map:0.81546	validation_1-map:0.80833
# [1786]	validation_0-map:0.81546	validation_1-map:0.80833
# [1787]	validation_0-map:0.81547	validation_1-map:0.80834
# [1788]	validation_0-map:0.81548	validation_1-map:0.80834
# [1789]	validation_0-map:0.81549	validation_1-map:0.80834
# [1790]	validation_0-map:0.81550	validation_1-map:0.80835
# [1791]	validation_0-map:0.81551	validation_1-map:0.80835
# [1792]	validation_0-map:0.81551	validation_1-map:0.80835
# [1793]	validation_0-map:0.81553	validation_1-map:0.80837
# [1794]	validation_0-map:0.81553	validation_1-map:0.80837
# [1795]	validation_0-map:0.81554	validation_1-map:0.80837
# [1796]	validation_0-map:0.81554	validation_1-map:0.80837
# [1797]	validation_0-map:0.81554	validation_1-map:0.80837
# [1798]	validation_0-map:0.81554	validation_1-map:0.80836
# [1799]	validation_0-map:0.81554	validation_1-map:0.80836
# [1800]	validation_0-map:0.81553	validation_1-map:0.80836
# [1801]	validation_0-map:0.81553	validation_1-map:0.80836
# [1802]	validation_0-map:0.81555	validation_1-map:0.80837
# [1803]	validation_0-map:0.81555	validation_1-map:0.80837
# [1804]	validation_0-map:0.81555	validation_1-map:0.80837
# [1805]	validation_0-map:0.81556	validation_1-map:0.80839
# [1806]	validation_0-map:0.81557	validation_1-map:0.80838
# [1807]	validation_0-map:0.81557	validation_1-map:0.80839
# [1808]	validation_0-map:0.81557	validation_1-map:0.80839
# [1809]	validation_0-map:0.81560	validation_1-map:0.80841
# [1810]	validation_0-map:0.81560	validation_1-map:0.80841
# [1811]	validation_0-map:0.81561	validation_1-map:0.80841
# [1812]	validation_0-map:0.81561	validation_1-map:0.80841
# [1813]	validation_0-map:0.81561	validation_1-map:0.80841
# [1814]	validation_0-map:0.81561	validation_1-map:0.80841
# [1815]	validation_0-map:0.81562	validation_1-map:0.80841
# [1816]	validation_0-map:0.81562	validation_1-map:0.80841
# [1817]	validation_0-map:0.81564	validation_1-map:0.80842
# [1818]	validation_0-map:0.81564	validation_1-map:0.80842
# [1819]	validation_0-map:0.81566	validation_1-map:0.80842
# [1820]	validation_0-map:0.81566	validation_1-map:0.80843
# [1821]	validation_0-map:0.81566	validation_1-map:0.80843
# [1822]	validation_0-map:0.81566	validation_1-map:0.80842
# [1823]	validation_0-map:0.81568	validation_1-map:0.80843
# [1824]	validation_0-map:0.81568	validation_1-map:0.80843
# [1825]	validation_0-map:0.81568	validation_1-map:0.80843
# [1826]	validation_0-map:0.81568	validation_1-map:0.80843
# [1827]	validation_0-map:0.81568	validation_1-map:0.80843
# [1828]	validation_0-map:0.81569	validation_1-map:0.80843
# [1829]	validation_0-map:0.81569	validation_1-map:0.80843
# [1830]	validation_0-map:0.81569	validation_1-map:0.80843
# [1831]	validation_0-map:0.81569	validation_1-map:0.80844
# [1832]	validation_0-map:0.81571	validation_1-map:0.80843
# [1833]	validation_0-map:0.81572	validation_1-map:0.80844
# [1834]	validation_0-map:0.81573	validation_1-map:0.80844
# [1835]	validation_0-map:0.81574	validation_1-map:0.80844
# [1836]	validation_0-map:0.81574	validation_1-map:0.80845
# [1837]	validation_0-map:0.81576	validation_1-map:0.80845
# [1838]	validation_0-map:0.81576	validation_1-map:0.80845
# [1839]	validation_0-map:0.81578	validation_1-map:0.80846
# [1840]	validation_0-map:0.81578	validation_1-map:0.80846
# [1841]	validation_0-map:0.81579	validation_1-map:0.80847
# [1842]	validation_0-map:0.81579	validation_1-map:0.80847
# [1843]	validation_0-map:0.81579	validation_1-map:0.80847
# [1844]	validation_0-map:0.81580	validation_1-map:0.80847
# [1845]	validation_0-map:0.81580	validation_1-map:0.80847
# [1846]	validation_0-map:0.81581	validation_1-map:0.80847
# [1847]	validation_0-map:0.81582	validation_1-map:0.80848
# [1848]	validation_0-map:0.81583	validation_1-map:0.80849
# [1849]	validation_0-map:0.81583	validation_1-map:0.80849
# [1850]	validation_0-map:0.81584	validation_1-map:0.80850
# [1851]	validation_0-map:0.81585	validation_1-map:0.80850
# [1852]	validation_0-map:0.81586	validation_1-map:0.80850
# [1853]	validation_0-map:0.81586	validation_1-map:0.80850
# [1854]	validation_0-map:0.81587	validation_1-map:0.80850
# [1855]	validation_0-map:0.81587	validation_1-map:0.80851
# [1856]	validation_0-map:0.81589	validation_1-map:0.80851
# [1857]	validation_0-map:0.81589	validation_1-map:0.80851
# [1858]	validation_0-map:0.81589	validation_1-map:0.80851
# [1859]	validation_0-map:0.81590	validation_1-map:0.80851
# [1860]	validation_0-map:0.81591	validation_1-map:0.80850
# [1861]	validation_0-map:0.81591	validation_1-map:0.80850
# [1862]	validation_0-map:0.81591	validation_1-map:0.80851
# [1863]	validation_0-map:0.81593	validation_1-map:0.80851
# [1864]	validation_0-map:0.81593	validation_1-map:0.80851
# [1865]	validation_0-map:0.81594	validation_1-map:0.80851
# [1866]	validation_0-map:0.81594	validation_1-map:0.80851
# [1867]	validation_0-map:0.81595	validation_1-map:0.80851
# [1868]	validation_0-map:0.81595	validation_1-map:0.80851
# [1869]	validation_0-map:0.81596	validation_1-map:0.80851
# [1870]	validation_0-map:0.81596	validation_1-map:0.80851
# [1871]	validation_0-map:0.81597	validation_1-map:0.80851
# [1872]	validation_0-map:0.81597	validation_1-map:0.80851
# [1873]	validation_0-map:0.81597	validation_1-map:0.80851
# [1874]	validation_0-map:0.81597	validation_1-map:0.80851
# [1875]	validation_0-map:0.81599	validation_1-map:0.80851
# [1876]	validation_0-map:0.81600	validation_1-map:0.80852
# [1877]	validation_0-map:0.81600	validation_1-map:0.80852
# [1878]	validation_0-map:0.81601	validation_1-map:0.80851
# [1879]	validation_0-map:0.81601	validation_1-map:0.80852
# [1880]	validation_0-map:0.81601	validation_1-map:0.80852
# [1881]	validation_0-map:0.81602	validation_1-map:0.80852
# [1882]	validation_0-map:0.81603	validation_1-map:0.80852
# [1883]	validation_0-map:0.81603	validation_1-map:0.80852
# [1884]	validation_0-map:0.81603	validation_1-map:0.80853
# [1885]	validation_0-map:0.81603	validation_1-map:0.80853
# [1886]	validation_0-map:0.81603	validation_1-map:0.80853
# [1887]	validation_0-map:0.81606	validation_1-map:0.80855
# [1888]	validation_0-map:0.81607	validation_1-map:0.80855
# [1889]	validation_0-map:0.81607	validation_1-map:0.80855
# [1890]	validation_0-map:0.81607	validation_1-map:0.80855
# [1891]	validation_0-map:0.81608	validation_1-map:0.80855
# [1892]	validation_0-map:0.81609	validation_1-map:0.80856
# [1893]	validation_0-map:0.81609	validation_1-map:0.80856
# [1894]	validation_0-map:0.81609	validation_1-map:0.80855
# [1895]	validation_0-map:0.81609	validation_1-map:0.80855
# [1896]	validation_0-map:0.81610	validation_1-map:0.80857
# [1897]	validation_0-map:0.81611	validation_1-map:0.80857
# [1898]	validation_0-map:0.81612	validation_1-map:0.80858
# [1899]	validation_0-map:0.81614	validation_1-map:0.80859
# [1900]	validation_0-map:0.81616	validation_1-map:0.80860
# [1901]	validation_0-map:0.81616	validation_1-map:0.80860
# [1902]	validation_0-map:0.81616	validation_1-map:0.80860
# [1903]	validation_0-map:0.81616	validation_1-map:0.80860
# [1904]	validation_0-map:0.81616	validation_1-map:0.80860
# [1905]	validation_0-map:0.81616	validation_1-map:0.80860
# [1906]	validation_0-map:0.81617	validation_1-map:0.80860
# [1907]	validation_0-map:0.81616	validation_1-map:0.80859
# [1908]	validation_0-map:0.81616	validation_1-map:0.80860
# [1909]	validation_0-map:0.81617	validation_1-map:0.80860
# [1910]	validation_0-map:0.81617	validation_1-map:0.80860
# [1911]	validation_0-map:0.81618	validation_1-map:0.80859
# [1912]	validation_0-map:0.81619	validation_1-map:0.80860
# [1913]	validation_0-map:0.81619	validation_1-map:0.80860
# [1914]	validation_0-map:0.81620	validation_1-map:0.80860
# [1915]	validation_0-map:0.81620	validation_1-map:0.80861
# [1916]	validation_0-map:0.81621	validation_1-map:0.80861
# [1917]	validation_0-map:0.81622	validation_1-map:0.80861
# [1918]	validation_0-map:0.81622	validation_1-map:0.80861
# [1919]	validation_0-map:0.81622	validation_1-map:0.80861
# [1920]	validation_0-map:0.81623	validation_1-map:0.80861
# [1921]	validation_0-map:0.81623	validation_1-map:0.80861
# [1922]	validation_0-map:0.81623	validation_1-map:0.80862
# [1923]	validation_0-map:0.81623	validation_1-map:0.80862
# [1924]	validation_0-map:0.81624	validation_1-map:0.80862
# [1925]	validation_0-map:0.81624	validation_1-map:0.80862
# [1926]	validation_0-map:0.81624	validation_1-map:0.80862
# [1927]	validation_0-map:0.81624	validation_1-map:0.80862
# [1928]	validation_0-map:0.81625	validation_1-map:0.80861
# [1929]	validation_0-map:0.81625	validation_1-map:0.80862
# [1930]	validation_0-map:0.81625	validation_1-map:0.80862
# [1931]	validation_0-map:0.81626	validation_1-map:0.80863
# [1932]	validation_0-map:0.81627	validation_1-map:0.80863
# [1933]	validation_0-map:0.81627	validation_1-map:0.80863
# [1934]	validation_0-map:0.81627	validation_1-map:0.80863
# [1935]	validation_0-map:0.81628	validation_1-map:0.80864
# [1936]	validation_0-map:0.81628	validation_1-map:0.80864
# [1937]	validation_0-map:0.81628	validation_1-map:0.80864
# [1938]	validation_0-map:0.81629	validation_1-map:0.80864
# [1939]	validation_0-map:0.81628	validation_1-map:0.80864
# [1940]	validation_0-map:0.81629	validation_1-map:0.80864
# [1941]	validation_0-map:0.81629	validation_1-map:0.80863
# [1942]	validation_0-map:0.81629	validation_1-map:0.80864
# [1943]	validation_0-map:0.81630	validation_1-map:0.80863
# [1944]	validation_0-map:0.81630	validation_1-map:0.80863
# [1945]	validation_0-map:0.81630	validation_1-map:0.80863
# [1946]	validation_0-map:0.81631	validation_1-map:0.80864
# [1947]	validation_0-map:0.81632	validation_1-map:0.80865
# [1948]	validation_0-map:0.81633	validation_1-map:0.80865
# [1949]	validation_0-map:0.81634	validation_1-map:0.80865
# [1950]	validation_0-map:0.81634	validation_1-map:0.80865
# [1951]	validation_0-map:0.81634	validation_1-map:0.80865
# [1952]	validation_0-map:0.81635	validation_1-map:0.80864
# [1953]	validation_0-map:0.81636	validation_1-map:0.80865
# [1954]	validation_0-map:0.81637	validation_1-map:0.80866
# [1955]	validation_0-map:0.81639	validation_1-map:0.80867
# [1956]	validation_0-map:0.81639	validation_1-map:0.80867
# [1957]	validation_0-map:0.81639	validation_1-map:0.80867
# [1958]	validation_0-map:0.81639	validation_1-map:0.80867
# [1959]	validation_0-map:0.81639	validation_1-map:0.80868
# [1960]	validation_0-map:0.81640	validation_1-map:0.80869
# [1961]	validation_0-map:0.81640	validation_1-map:0.80869
# [1962]	validation_0-map:0.81640	validation_1-map:0.80869
# [1963]	validation_0-map:0.81639	validation_1-map:0.80869
# [1964]	validation_0-map:0.81639	validation_1-map:0.80869
# [1965]	validation_0-map:0.81640	validation_1-map:0.80870
# [1966]	validation_0-map:0.81640	validation_1-map:0.80869
# [1967]	validation_0-map:0.81640	validation_1-map:0.80870
# [1968]	validation_0-map:0.81640	validation_1-map:0.80870
# [1969]	validation_0-map:0.81642	validation_1-map:0.80871
# [1970]	validation_0-map:0.81643	validation_1-map:0.80871
# [1971]	validation_0-map:0.81643	validation_1-map:0.80871
# [1972]	validation_0-map:0.81643	validation_1-map:0.80871
# [1973]	validation_0-map:0.81643	validation_1-map:0.80871
# [1974]	validation_0-map:0.81644	validation_1-map:0.80871
# [1975]	validation_0-map:0.81645	validation_1-map:0.80871
# [1976]	validation_0-map:0.81645	validation_1-map:0.80872
# [1977]	validation_0-map:0.81645	validation_1-map:0.80872
# [1978]	validation_0-map:0.81645	validation_1-map:0.80872
# [1979]	validation_0-map:0.81645	validation_1-map:0.80872
# [1980]	validation_0-map:0.81645	validation_1-map:0.80871
# [1981]	validation_0-map:0.81645	validation_1-map:0.80871
# [1982]	validation_0-map:0.81645	validation_1-map:0.80872
# [1983]	validation_0-map:0.81647	validation_1-map:0.80873
# [1984]	validation_0-map:0.81648	validation_1-map:0.80874
# [1985]	validation_0-map:0.81648	validation_1-map:0.80874
# [1986]	validation_0-map:0.81648	validation_1-map:0.80874
# [1987]	validation_0-map:0.81648	validation_1-map:0.80874
# [1988]	validation_0-map:0.81648	validation_1-map:0.80874
# [1989]	validation_0-map:0.81650	validation_1-map:0.80874
# [1990]	validation_0-map:0.81650	validation_1-map:0.80874
# [1991]	validation_0-map:0.81651	validation_1-map:0.80874
# [1992]	validation_0-map:0.81651	validation_1-map:0.80874
# [1993]	validation_0-map:0.81653	validation_1-map:0.80875
# [1994]	validation_0-map:0.81653	validation_1-map:0.80875
# [1995]	validation_0-map:0.81654	validation_1-map:0.80875
# [1996]	validation_0-map:0.81654	validation_1-map:0.80875
# [1997]	validation_0-map:0.81655	validation_1-map:0.80875
# [1998]	validation_0-map:0.81655	validation_1-map:0.80875
# [1999]	validation_0-map:0.81656	validation_1-map:0.80875
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.25,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric='map', feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=5, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=2000, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %% [markdown]
# ### meu xgboost

# %%
xgb = XGBClassifier(learning_rate=0.1, max_depth=25, min_child_weight=16, n_estimators=100, n_jobs=1, subsample=0.8500000000000001, verbosity=0)

# %%
scores_xgb = cross_validate(xgb, X, y, cv=splitter, scoring=METRICS)
xgb_scores = pd.DataFrame(scores_xgb)
pd.DataFrame(xgb_scores.mean()).T

# %%
# train/test
xgb.fit(xtrain, ytrain)
ypred = xgb.predict(xtest)
cm = confusion_matrix(ytest,ypred) 
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
f1 = (2*tp)/(2*tp+fp+fn)
print(f1)

# %% [markdown]
# - ## pipeline?

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline, make_union
from tpot.builtins import StackingEstimator
from xgboost import XGBClassifier
from tpot.export_utils import set_param_recursive
from sklearn.preprocessing import MaxAbsScaler

# %%
#exported_pipeline = make_pipeline(
#    StackingEstimator(estimator=XGBClassifier(learning_rate=0.1, max_depth=8, min_child_weight=16, n_estimators=100, n_jobs=1, subsample=0.8500000000000001, verbosity=0)),
#    StackingEstimator(estimator=RandomForestClassifier(bootstrap=False, criterion="entropy", max_features=0.4, min_samples_leaf=9, min_samples_split=18, n_estimators=100)),
#    MultinomialNB(alpha=1.0, fit_prior=False)
#)
exported_pipeline = make_pipeline(
    MaxAbsScaler(),
    StackingEstimator(estimator=RandomForestClassifier(bootstrap=False, criterion="gini", max_features=0.45, min_samples_leaf=17, min_samples_split=10, n_estimators=100)),
    XGBClassifier(learning_rate=0.01, max_depth=2, min_child_weight=7, n_estimators=100, n_jobs=1, subsample=0.45, verbosity=0)
)

# %%
# Fix random state for all the steps in exported pipeline
set_param_recursive(exported_pipeline.steps, 'random_state', 1)

# %%
exported_pipeline.fit(xtrain, ytrain)
ypred = exported_pipeline.predict(xtest)
cm = confusion_matrix(ytest,ypred)
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
pipe_f1 = (2*tp)/(2*tp+fp+fn)
print(pipe_f1)

# %%
results = exported_pipeline.predict(xtest)

# %%
cm = confusion_matrix(ytest,ypred)

# %%
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
pipe_f1 = (2*tp)/(2*tp+fp+fn)
print(pipe_f1)

# %% [markdown]
# # param optimize

# %%
from sklearn.model_selection import RandomizedSearchCV
model = XGBClassifier()
param_vals = {'max_depth': [200, 500, 800, 1100], 'n_estimators': [100, 200, 300, 400],
              'learning_rate': [0.001, 0.01, 0.1, 1, 10]}
random_rf = RandomizedSearchCV(estimator=model, param_distributions=param_vals,
                              n_iter=10, scoring='f1', cv=5,
                              refit=True, n_jobs=-1)

# %%
#Training and prediction
random_rf.fit(xtrain, ytrain)
preds = random_rf.best_estimator_.predict(xtest)

# %%
cm = confusion_matrix(ytest,ypred) 
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
f1 = (2*tp)/(2*tp+fp+fn)
print(f1)

# %% [markdown]
# ## ensembles
# - https://towardsdatascience.com/ensemble-learning-using-scikit-learn-85c4531ff86a

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# - ## K-Nearest Neighbors

# %%
#fix asap
d = d.dropna()

# %%
X, y = d.drop("target", axis=1), d["target"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y)

# %%
#create new a knn model
knn = KNeighborsClassifier()
#create a dictionary of all values we want to test for n_neighbors
params_knn = {'n_neighbors': np.arange(1, 25)}
#use gridsearch to test all values for n_neighbors
knn_gs = GridSearchCV(knn, params_knn, cv=5)
#fit model to training data
knn_gs.fit(X_train, y_train)

# %%
#save best model
knn_best = knn_gs.best_estimator_
#check best n_neigbors value
print(knn_gs.best_params_)

# %% [markdown]
# - ## Random Forest

# %%
#create a new random forest classifier
rf = RandomForestClassifier()
#create a dictionary of all values we want to test for n_estimators
params_rf = {'n_estimators': [50, 100, 200]}
#use gridsearch to test all values for n_estimators
rf_gs = GridSearchCV(rf, params_rf, cv=5)
#fit model to training data
rf_gs.fit(X_train, y_train)

# %%
#save best model
rf_best = rf_gs.best_estimator_
#check best n_estimators value
print(rf_gs.best_params_)

# %% [markdown]
# - ## Logistic Regression

# %%
#create a new logistic regression model
log_reg = LogisticRegression()
#fit the model to the training data
log_reg.fit(X_train, y_train)

# %% [markdown]
# resultados dos 3

# %%
#test the three models with the test data and print their accuracy scores
print('knn: {}'.format(knn_best.score(X_test, y_test)))
print('rf: {}'.format(rf_best.score(X_test, y_test)))
print('log_reg: {}'.format(log_reg.score(X_test, y_test)))

# %% [markdown]
# - ## Voting Classifier
# resultado do conjunto dos 3

# %%
from sklearn.ensemble import VotingClassifier
#create a dictionary of our models
estimators=[('knn', knn_best), ('rf', rf_best), ('log_reg', log_reg)]
#create our voting classifier, inputting our models
ensemble = VotingClassifier(estimators, voting='hard')

# %%
#fit model to training data
ensemble.fit(X_train, y_train)
#test our model on the test data
ensemble.score(X_test, y_test)

# %%
ypred = ensemble.predict(xtest)
cm = confusion_matrix(ytest,ypred)
tp,fp,fn,tn = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
ensemble_f1 = (2*tp)/(2*tp+fp+fn)
print(ensemble_f1)
