# %%
import pandas as pd
import numpy as np
# %run -i create_target.py

# %% [markdown]
# # Scenario 1
# scenario 1 is just the numeric data with no processing

# %% [markdown]
# ## import data

# %% [markdown]
# import csv to df

# %%
df = pd.read_csv("dados/00-merged.csv")

# %% [markdown]
# ## create target

# %%
create_target(df)
# Out:
# E:\Programas\Anaconda\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# target
# 0.0    0.519959
# 1.0    0.480041
# dtype: float64

# %% [markdown]
# ## select only numeric data

# %%
df = df[["week_number","sales_depot_id","sales_channel_id","route_id","client_id","product_id","target"]]
# Out:
#         Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0            5        1936         1      1158     1575677         2425
# 1            6        1310         1      2005       32695        43066
# 2            3        2029         1      1126     1048394         1309
# 3            4        2022         1      1221     2036290         1278
# 4            4        4041         1      1054      153108         5707
# ...        ...         ...       ...       ...         ...          ...
# 971971       9        1423         4      4906     1436346        34054
# 971972       7        1121         1      1202     4448718         1125
# 971973       8        1632         1      1212      623879         1240
# 971974       7        1123         1      1001     2414065        48077
# 971975       7        1613         1      2850     1505796        37361
#
#         Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  \
# ...

# %% [markdown]
# ## save to csv

# %%
df.to_csv('data/01-apenas-numericos.csv',index=False)
